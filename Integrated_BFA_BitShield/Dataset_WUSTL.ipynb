# %%
from __future__ import division
from __future__ import absolute_import
import torch.nn.functional as F

import os, sys, random
import time
import copy
import torch
import torch.backends.cudnn as cudnn
import torchvision.datasets as dset
import torchvision.transforms as transforms
import pandas as pd
import numpy as np
from torch.utils.tensorboard import SummaryWriter
import logging
from sklearn.model_selection import train_test_split
from sklearn.metrics import matthews_corrcoef
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from sklearn.preprocessing import StandardScaler, LabelEncoder
import math
# Out:
# 2025-04-23 12:36:59.217706: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-04-23 12:36:59.217736: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-23 12:36:59.218562: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-23 12:36:59.223584: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
class RecorderMeter(object):
    """Computes and stores the minimum loss value and its epoch index, along with MCC"""

    def __init__(self, total_epoch):
        self.reset(total_epoch)

    def reset(self, total_epoch):
        assert total_epoch > 0
        self.total_epoch = total_epoch
        self.current_epoch = 0
        self.epoch_losses = np.zeros((self.total_epoch, 2), dtype=np.float32)  # [epoch, train/val]
        self.epoch_losses = self.epoch_losses - 1

        self.epoch_mcc = np.zeros((self.total_epoch, 2), dtype=np.float32)  # [epoch, train/val]
        self.epoch_mcc = self.epoch_mcc

    def update(self, idx, train_loss, train_mcc, val_loss, val_mcc):
        assert idx >= 0 and idx < self.total_epoch, 'total_epoch : {} , but update with the {} index'.format(
            self.total_epoch, idx)
        self.epoch_losses[idx, 0] = train_loss
        self.epoch_losses[idx, 1] = val_loss
        self.epoch_mcc[idx, 0] = train_mcc
        self.epoch_mcc[idx, 1] = val_mcc
        self.current_epoch = idx + 1

    def max_mcc(self, istrain):
        if self.current_epoch <= 0:
            return 0
        if istrain:
            return self.epoch_mcc[:self.current_epoch, 0].max()
        else:
            return self.epoch_mcc[:self.current_epoch, 1].max()

# %%
def time_string():
    ISOTIMEFORMAT = '%Y-%m-%d %X'
    string = '[{}]'.format(
        time.strftime(ISOTIMEFORMAT, time.gmtime(time.time())))
    return string


def convert_secs2time(epoch_time):
    need_hour = int(epoch_time / 3600)
    need_mins = int((epoch_time - 3600 * need_hour) / 60)
    need_secs = int(epoch_time - 3600 * need_hour - 60 * need_mins)
    return need_hour, need_mins, need_secs


def time_file_str():
    ISOTIMEFORMAT = '%Y-%m-%d'
    string = '{}'.format(time.strftime(ISOTIMEFORMAT,
                                       time.gmtime(time.time())))
    return string + '-{}'.format(random.randint(1, 10000))

# %% [markdown]
# ### Class quan_Linear

# %%
class quan_Linear(nn.Linear):
    def __init__(self, in_features, out_features, bias=True):
        super(quan_Linear, self).__init__(in_features, out_features, bias=bias)

        self.N_bits = 8
        self.full_lvls = 2**self.N_bits
        self.half_lvls = (self.full_lvls - 2) / 2
        # Initialize the step size
        self.step_size = nn.Parameter(torch.Tensor([1]), requires_grad=True)
        self.__reset_stepsize__()
        # flag to enable the inference with quantized weight or self.weight
        self.inf_with_weight = False  # disabled by default

        # create a vector to identify the weight to each bit
        self.b_w = nn.Parameter(2**torch.arange(start=self.N_bits - 1,
                                                end=-1,
                                                step=-1).unsqueeze(-1).float(),
                                requires_grad=False)

        self.b_w[0] = -self.b_w[0]  #in-place reverse

    def forward(self, input):
        if self.inf_with_weight:
            return F.linear(input, self.weight * self.step_size, self.bias)
        else:
            self.__reset_stepsize__()
            weight_quan = quantize(self.weight, self.step_size,
                                   self.half_lvls) * self.step_size
            return F.linear(input, weight_quan, self.bias)

    def __reset_stepsize__(self):
        with torch.no_grad():
            self.step_size.data = self.weight.abs().max() / self.half_lvls

    def __reset_weight__(self):
        '''
        This function will reconstruct the weight stored in self.weight.
        Replacing the orginal floating-point with the quantized fix-point
        weight representation.
        '''
        # replace the weight with the quantized version
        with torch.no_grad():
            self.weight.data = quantize(self.weight, self.step_size,
                                        self.half_lvls)
        # enable the flag, thus now computation does not invovle weight quantization
        self.inf_with_weight = True

# %% [markdown]
# ### Class quan_Conv1d

# %%
class quan_Conv1d(nn.Conv1d):
    def __init__(self,
                 in_channels,
                 out_channels,
                 kernel_size,
                 stride=1,
                 padding=1,
                 dilation=1,
                 groups=1,
                 bias=True):
        super(quan_Conv1d, self).__init__(in_channels,
                                          out_channels,
                                          kernel_size,
                                          stride=stride,
                                          padding=padding,
                                          dilation=dilation,
                                          groups=groups,
                                          bias=bias)

        # Số lượng bit để lượng tử hóa trọng số
        self.N_bits = 8
        self.full_lvls = 2 ** self.N_bits
        self.half_lvls = (self.full_lvls - 2) / 2

        # Bước lượng tử hóa (step size), là một tham số có thể học được
        self.step_size = nn.Parameter(torch.Tensor([1]), requires_grad=True)
        self.__reset_stepsize__()

        # Cờ để bật hoặc tắt sử dụng trọng số lượng tử hóa
        self.inf_with_weight = False  # Tắt theo mặc định

        # Tạo một vector để biểu diễn trọng số cho từng bit
        self.b_w = nn.Parameter(2 ** torch.arange(start=self.N_bits - 1,
                                                  end=-1,
                                                  step=-1).unsqueeze(-1).float(),
                                requires_grad=False)
        self.b_w[0] = -self.b_w[0]  # Biến đổi MSB thành giá trị âm để hỗ trợ bù hai

    def __reset_stepsize__(self):
        """Hàm này dùng để đặt lại giá trị `step_size`."""
        # Giá trị này có thể được tùy chỉnh tùy thuộc vào yêu cầu của mô hình
        self.step_size.data.fill_(1.0)

    def forward(self, x):
        # Kiểm tra cờ `inf_with_weight` để quyết định sử dụng trọng số đã lượng tử hóa hay không
        if self.inf_with_weight:
            quantized_weight = self.quantize_weight(self.weight)
            return nn.functional.conv1d(x, quantized_weight, self.bias, self.stride,
                                        self.padding, self.dilation, self.groups)
        else:
            return nn.functional.conv1d(x, self.weight, self.bias, self.stride,
                                        self.padding, self.dilation, self.groups)

    def quantize_weight(self, weight):
        """Lượng tử hóa trọng số theo số bit đã định."""
        # Tạo trọng số lượng tử hóa bằng cách sử dụng step_size
        quantized_weight = torch.round(weight / self.step_size) * self.step_size
        quantized_weight = torch.clamp(quantized_weight, -self.half_lvls * self.step_size,
                                       (self.half_lvls - 1) * self.step_size)
        return quantized_weight

# %%
def change_quan_bitwidth(model, n_bit):
    '''This script change the quantization bit-width of entire model to n_bit'''
    for m in model.modules():
        if isinstance(m, quan_Conv1d) or isinstance(m, quan_Linear):
            m.N_bits = n_bit
            # print("Change weight bit-width as {}.".format(m.N_bits))
            m.b_w.data = m.b_w.data[-m.N_bits:]
            m.b_w[0] = -m.b_w[0]
            print(m.b_w)
    return

# %%
class _quantize_func(torch.autograd.Function):
    @staticmethod
    def forward(ctx, input, step_size, half_lvls):
        # ctx is a context object that can be used to stash information
        # for backward computation
        ctx.step_size = step_size
        ctx.half_lvls = half_lvls
        output = F.hardtanh(input,
                            min_val=-ctx.half_lvls * ctx.step_size.item(),
                            max_val=ctx.half_lvls * ctx.step_size.item())

        output = torch.round(output / ctx.step_size)
        return output

    @staticmethod
    def backward(ctx, grad_output):
        grad_input = grad_output.clone() / ctx.step_size

        return grad_input, None, None

quantize = _quantize_func.apply

# %%
class _bin_func(torch.autograd.Function):

    @staticmethod
    def forward(ctx, input, mu):
        ctx.mu = mu
        output = input.clone().zero_()
        output[input.ge(0)] = 1
        output[input.lt(0)] = -1

        return output

    @staticmethod
    def backward(ctx, grad_output):
        grad_input = grad_output.clone() / ctx.mu
        return grad_input, None

w_bin = _bin_func.apply

# %%
def quantize(tensor, step_size, half_lvls):
    """Quantization function."""
    return torch.clamp(torch.round(tensor / step_size), min=-half_lvls, max=half_lvls)

# %% [markdown]
# ### Class CustomBlock

# %%
class CustomBlock(nn.Module):
    def __init__(self, in_features, out_features, bias=True, apply_softmax=False):
        super(CustomBlock, self).__init__()
        self.N_bits = 16
        self.full_lvls = 2 ** self.N_bits
        self.half_lvls = (self.full_lvls - 2) / 2
        self.apply_softmax = apply_softmax

        # Initialize the step size
        self.step_size = nn.Parameter(torch.Tensor([1]), requires_grad=True)

        # Initialize weights and bias
        self.weight = nn.Parameter(torch.Tensor(out_features, in_features))
        self.bias = nn.Parameter(torch.Tensor(out_features)) if bias else None

        # Reset parameters
        self.__reset_stepsize__()
        self.reset_parameters()

        # Flag for inference with quantized weights
        self.inf_with_weight = False

        self.b_w = nn.Parameter(2**torch.arange(start=self.N_bits - 1,
                                             end=-1,
                                             step=-1).unsqueeze(-1).float(),
                           requires_grad=False)
        self.b_w[0] = -self.b_w[0]  #in-place reverse
        
    def reset_parameters(self):
        nn.init.kaiming_uniform_(self.weight, a=5 ** 0.5)
        if self.bias is not None:
            nn.init.zeros_(self.bias)

    def forward(self, input):
        if self.inf_with_weight:
            weight_applied = self.weight * self.step_size
        else:
            self.__reset_stepsize__()
            weight_quan = quantize(self.weight, self.step_size, self.half_lvls) * self.step_size
            weight_applied = weight_quan

        # Linear transformation
        input = input.view(input.size(0), -1)  # Flatten input to 2D for matmul
        output = input @ weight_applied.T
        if self.bias is not None:
            output += self.bias

        if self.apply_softmax:
            output = F.softmax(output, dim=-1)
        return output

    def __reset_stepsize__(self):
        with torch.no_grad():
            self.step_size.data = self.weight.abs().max() / self.half_lvls

    def __reset_weight__(self):
        with torch.no_grad():
            self.weight.data = quantize(self.weight, self.step_size, self.half_lvls)
        self.inf_with_weight = True

# %%
class DownsampleA(nn.Module):
    def __init__(self, nIn, nOut, stride):
        super(DownsampleA, self).__init__()
        assert stride == 2
        self.avg = nn.AvgPool1d(kernel_size=1, stride=stride)

    def forward(self, x):
        x = self.avg(x)
        return torch.cat((x, x.mul(0)), 1)
        
class SEBlock(nn.Module):
    expansion = 1

    def __init__(self, inplanes, planes, stride=1, downsample=None):
        super(SEBlock, self).__init__()
        self.conv_a = quan_Conv1d(inplanes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn_a = nn.BatchNorm1d(planes)
        self.dropout_a = nn.Dropout(p=0.3)  # Dropout sau BatchNorm

        self.conv_b = quan_Conv1d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn_b = nn.BatchNorm1d(planes)
        self.dropout_b = nn.Dropout(p=0.3)  # Dropout sau BatchNorm

        self.downsample = downsample

    def forward(self, x):
        residual = x
        
        basicblock = self.conv_a(x)
        basicblock = self.bn_a(basicblock)
        basicblock = F.relu(basicblock, inplace=True)
        basicblock = self.dropout_a(basicblock)  # Áp dụng dropout

        basicblock = self.conv_b(basicblock)
        basicblock = self.bn_b(basicblock)
        basicblock = self.dropout_b(basicblock)  # Áp dụng dropout

        if self.downsample:
            residual = self.downsample(x)

        return F.relu(residual + basicblock, inplace=True)

# %% [markdown]
# ### Class CustomModel

# %%
class CustomModel(nn.Module):
    def __init__(self, input_size=42, hidden_sizes=[32, 64, 128, 256, 512], output_size=5):
        super(CustomModel, self).__init__()
        self.fc1 = quan_Conv1d(input_size, hidden_sizes[0], kernel_size=3, stride=1, padding=1)
        self.bn_1 = nn.BatchNorm1d(hidden_sizes[0])

        self.inplanes = 32
        self.stage_1 = self._make_layer(SEBlock, 32, 16, 1)
        self.stage_2 = self._make_layer(SEBlock, 64, 16, 2)
        self.stage_3 = self._make_layer(SEBlock, 128, 16, 2)
        self.avgpool = nn.AdaptiveAvgPool1d(1)

        self.classifier = CustomBlock(128 * SEBlock.expansion, output_size)

        for m in self.modules():
            if isinstance(m, nn.Conv1d):
                n = m.kernel_size[0] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
                #m.bias.data.zero_()
            elif isinstance(m, nn.BatchNorm1d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
            elif isinstance(m, nn.Linear):
                init.kaiming_normal(m.weight)
                m.bias.data.zero_()
        
    def _make_layer(self, block, planes, blocks, stride=1):
        downsample = None
        downsample = None
        if stride == 2 or self.inplanes != planes * SEBlock.expansion:
            downsample = DownsampleA(self.inplanes, planes * SEBlock.expansion, stride) if stride == 2 else None

        layers = []
        layers.append(block(self.inplanes, planes, stride=1, downsample=downsample))
        self.inplanes = planes * SEBlock.expansion
        for i in range(1, blocks):
            layers.append(block(self.inplanes, planes))

        return nn.Sequential(*layers)
    def forward(self, x):
        x = self.fc1(x)
        x = F.relu(self.bn_1(x), inplace=True)
        
        x = self.stage_1(x)
        x = self.stage_2(x)
        x = self.stage_3(x)

        x = self.avgpool(x)
        x = x.view(x.size(0), -1)
        return self.classifier(x)

# %% [markdown]
# ### Class CustomModel2

# %%
class CustomModel2(nn.Module):
    def __init__(self, input_size=42, hidden_sizes=[32, 64, 128, 100], output_size=5):
        super(CustomModel2, self).__init__()
        self.hidden_sizes = hidden_sizes

        # Define layers
        self.fc1 = nn.Conv1d(input_size, hidden_sizes[0], kernel_size=3, stride=2, padding=1)
        self.pool = nn.AdaptiveMaxPool1d(1)
        self.activation = nn.ReLU()
        self.dropout = nn.Dropout(0.1)
        
        self.stage_1 = nn.Conv1d(hidden_sizes[0], hidden_sizes[1], kernel_size=3, stride=2, padding=1)
        self.stage_2 = nn.Conv1d(hidden_sizes[1], hidden_sizes[2], kernel_size=3, stride=2, padding=1)
        self.stage_3 = nn.Conv1d(hidden_sizes[2], hidden_sizes[3], kernel_size=3, stride=2, padding=1)

        # Global Pooling
        self.global_pool = nn.AdaptiveAvgPool1d(1)

        # Classifier
        self.classifier = CustomBlock(hidden_sizes[-1], output_size, apply_softmax=True)
        nn.Dropout(0.15)
        
    def forward(self, x):
        # Pass through layers
        x = self.fc1(x)
        x = self.activation(self.pool(x))

        x = self.stage_1(x)
        x = self.activation(self.pool(x))

        x = self.stage_2(x)
        x = self.activation(self.pool(x))

        x = self.stage_3(x)
        x = self.activation(self.pool(x))

        # Global Pooling
        x = self.global_pool(x)
        x = x.view(x.size(0), -1)  # Flatten
        return self.classifier(x)

# %% [markdown]
# ### Init dataset

# %%
class Args:
    def __init__(self):
        self.arch = 'CustomModel'
        self.data_path = '../../dataset/'
        self.dataset = 'inid'
        self.save_path = './save/attack_random'
        self.epochs = 20
        self.optimizer = 'SGD'
        self.test_batch_size = 32
        self.learning_rate = 0.001
        self.momentum = 0.9
        self.decay = 1e-4
        self.schedule = [80, 120]
        self.gammas = [0.1, 0.1]
        self.print_freq = 100
        self.resume = 'save\model_best.pth.tar'
        self.start_epoch = 0
        self.enable_bfa = False
        self.evaluate = False
        self.ngpu = 1
        self.gpu_id = 0
        self.workers = 4
        self.manualSeed = None
        self.quan_bitwidth = 16
        self.reset_weight = False
        self.bfa = True
        self.attack_sample_size = 128
        self.n_iter = 25
        self.k_top = None
        self.random_bfa = True
        self.progressive_bit_search= True
        self.random_flip = True
        self.clustering = False
        self.lambda_coeff = 1e-3
        self.use_cuda = True  

args = Args()
args.use_cuda = torch.cuda.is_available()

# %%
# Thiết lập cấu hình logging
logging.basicConfig(level=logging.INFO, format='%(message)s')
logger = logging.getLogger()

# Init logger
if not os.path.isdir(args.save_path):
    os.makedirs(args.save_path)

# Tạo tệp log
log_file_path = os.path.join(args.save_path, 'log_seed_{}.txt'.format(args.manualSeed))
file_handler = logging.FileHandler(log_file_path)
file_handler.setLevel(logging.INFO)

# Định dạng cho tệp log
formatter = logging.Formatter('%(asctime)s - %(message)s')
file_handler.setFormatter(formatter)

# Thêm file handler vào logger
logger.addHandler(file_handler)

# Ghi log vào console và tệp
logger.info('Save path: {}'.format(args.save_path))
state = {k: getattr(args, k) for k in dir(args) if not k.startswith('__')}
logger.info('State: {}'.format(state))
logger.info("Random Seed: {}".format(args.manualSeed))
logger.info("Python version: {}".format(sys.version.replace('\n', ' ')))
logger.info("Torch version: {}".format(torch.__version__))
logger.info("CUDNN version: {}".format(torch.backends.cudnn.version()))

# Init the tensorboard path and writer
tb_path = os.path.join(args.save_path, 'tb_log', 'run_' + str(args.manualSeed))
writer = SummaryWriter(tb_path)
# Out:
# Save path: ./save/attack_random
# State: {'arch': 'CustomModel', 'attack_sample_size': 128, 'bfa': True, 'clustering': False, 'data_path': '../../dataset/', 'dataset': 'inid', 'decay': 0.0001, 'enable_bfa': False, 'epochs': 20, 'evaluate': False, 'gammas': [0.1, 0.1], 'gpu_id': 0, 'k_top': None, 'lambda_coeff': 0.001, 'learning_rate': 0.001, 'manualSeed': None, 'momentum': 0.9, 'n_iter': 25, 'ngpu': 1, 'optimizer': 'SGD', 'print_freq': 100, 'progressive_bit_search': True, 'quan_bitwidth': 16, 'random_bfa': True, 'random_flip': True, 'reset_weight': False, 'resume': 'save\\model_best.pth.tar', 'save_path': './save/attack_random', 'schedule': [80, 120], 'start_epoch': 0, 'test_batch_size': 32, 'use_cuda': True, 'workers': 4}
# Random Seed: None
# Python version: 3.10.14 | packaged by conda-forge | (main, Mar 20 2024, 12:45:18) [GCC 12.3.0]
# Torch version: 2.2.2+cu118
# CUDNN version: 8907

# %%
# Init dataset
if not os.path.isdir(args.data_path):
    os.makedirs(args.data_path)

if args.dataset == 'inid':
    print("Inid dataset import sucsess!")
else:
    assert False, "Unknow dataset : {}".format(args.dataset)
# Out:
# Inid dataset import sucsess!

# %% [markdown]
# ### Xử lý dữ liệu

# %%
# Init dataset
if args.dataset == 'inid':
    data = pd.read_csv("../../dataset/wustl_iiot_2021_reduced.csv",
                               skipinitialspace=True)
    data = data.drop_duplicates()
    columns_to_remove = ['StartTime', 'LastTime', 'SrcAddr', 'DstAddr', 'sIpId', 'dIpId']
    data.drop(columns=columns_to_remove, inplace=True, errors='ignore')
    
    
    datalabel = data[['Traffic']]
    data = data.drop(columns=['Traffic'])
    
    scaler = StandardScaler()
    onc = LabelEncoder()
    
    # Tách dữ liệu thành tập huấn luyện và tập kiểm tra
    X_train, X_test, y_train, y_test = train_test_split(data, datalabel, test_size=0.2, random_state=42)
    X_train= scaler.fit_transform(X_train)
    X_test= scaler.transform(X_test)
    print(y_train['Traffic'])
    # Chuyển đổi y_train và y_test thành mã số
    y_train = onc.fit_transform(y_train['Traffic'].to_numpy().reshape(-1,1))  # Chuyển đổi thành mã số
    y_test= onc.transform(y_test['Traffic'].to_numpy().reshape(-1,1))  # Chuyển đổi thành mã số
    
    # Kiểm tra kiểu dữ liệu của y_train và y_test
    print("Kiểu dữ liệu y_train:", y_train.shape)
    print("Kiểu dữ liệu y_test:", y_test.shape)
    
    # Tạo DataLoader cho tập huấn luyện
    train_loader = DataLoader(
        torch.utils.data.TensorDataset(
            torch.FloatTensor(X_train),
            torch.LongTensor(y_train)  # y_train đã được chuyển đổi thành mã số
        ),
        batch_size=256,
        num_workers=8,
        shuffle=True,
        pin_memory=True
    )
    
    # Tạo DataLoader cho tập kiểm tra
    test_loader = DataLoader(
        torch.utils.data.TensorDataset(
            torch.FloatTensor(X_test),
            torch.LongTensor(y_test)  # y_test đã được chuyển đổi thành mã số
        ),
        batch_size=256,
        num_workers=8,
        shuffle=False,
        pin_memory=True
    )
else:
    train_loader = torch.utils.data.DataLoader(
        train_data,
        batch_size=args.attack_sample_size,
        shuffle=True,
        num_workers=args.workers,
        pin_memory=True)
    test_loader = torch.utils.data.DataLoader(test_data,
                                              batch_size=args.test_batch_size,
                                              shuffle=False,
                                              num_workers=args.workers,
                                              pin_memory=True)

logger.info("=> creating model '{}'".format(args.arch))
data
# Out:
# /opt/tljh/user/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/tljh/user/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# => creating model 'CustomModel'
# 29625        DoS
# 9585      normal
# 608618    normal
# 667287    normal
# 521918    normal
#            ...
# 259178    normal
# 365838    normal
# 131932    normal
# 671155    normal
# 121958    normal
# Name: Traffic, Length: 559997, dtype: object
# Kiểu dữ liệu y_train: (559997,)
# Kiểu dữ liệu y_test: (140000,)
#         Mean  Sport  Dport  SrcPkts  DstPkts  TotPkts  DstBytes  SrcBytes  \
# 0          0  54134    502        6        6       12       386       396
# 1          4  28031    502      110        0      110         0      8360
# 2          0  61809    502       10        8       18       508       644
# 3          1  37474     80        4        0        4         0       248
# 4          0  62644    502        6        6       12       384       396
# ...      ...    ...    ...      ...      ...      ...       ...       ...
# 699992     0  62204    502       10        8       18       508       644
# 699993     0  54676    502       10        8       18       508       644
# 699994     0  49410    502       10        8       18       508       644
# 699995     2  63526     80        4        0        4         0       248
# 699996     0  55746    502       10        8       18       508       644
#
#         TotBytes       SrcLoad  ...  dTtl  SAppBytes  DAppBytes  TotAppByte  \
# 0            782  82657.562500  ...    64         24         22          46
# 1           8360  13311.402344  ...     0       3520          0        3520
# 2           1152  69684.312500  ...    64         24         20          44
# 3            248   1044.395264  ...     0          0          0           0
# 4            780  77453.421875  ...    64         24         20          44
# ...          ...           ...  ...   ...        ...        ...         ...
# 699992      1152  88662.984375  ...    64         24         20          44
# 699993      1152  88718.929688  ...    64         24         20          44
# 699994      1152  89618.539062  ...    64         24         20          44
# 699995       248    556.956665  ...     0          0          0           0
# 699996      1152  88674.843750  ...    64         24         20          44
#
#           SynAck   RunTime  sTos    SrcJitAct  DstJitAct  Target
# 0       0.000648  0.031939     0     0.000000        0.0       0
# 1       0.000000  4.978589     0    88.529836        0.0       1
# 2       0.001251  0.066586     0     0.000000        0.0       0
# 3       0.000000  1.424748     0   712.373000        0.0       1
# 4       0.001211  0.034085     0     0.000000        0.0       0
# ...          ...       ...   ...          ...        ...     ...
# 699992  0.000659  0.052333     0     0.000000        0.0       0
# 699993  0.000645  0.052300     0     0.000000        0.0       0
# 699994  0.000740  0.051775     0     0.000000        0.0       0
# 699995  0.000000  2.671662     0  1259.432125        0.0       1
# 699996  0.000752  0.052326     0     0.000000        0.0       0
#
# [699997 rows x 42 columns]

# %%
def mcc_score(preds, targets):
    preds = preds.cpu().numpy()
    targets = targets.cpu().numpy()
    return matthews_corrcoef(targets, preds)

# %%
def mcc2(outputs_label, y_label_batch, y_cat_batch):
    """Compute MCC for each output of the model (label, category, sub-category)."""
    with torch.no_grad():
        # Ensure target has at least one dimension
        if y_label_batch.dim() == 0:
            y_label_batch = y_label_batch.unsqueeze(0)
     
      

        # Get the predicted classes (top-1 prediction) for each output
        _, pred_label = outputs_label.topk(1, 1, True, True)

        # Compute MCC for each output type
        mcc_label = mcc_score(pred_label.view(-1), y_label_batch)


        return mcc_label


def mcc(output, target):
    """Compute the Matthews Correlation Coefficient (MCC) for the given output and target."""
    with torch.no_grad():
        # Ensure target has at least one dimension
        if target.dim() == 0:
            target = target.unsqueeze(0)

        # Get the predicted classes (top-1 prediction)
        _, pred = output.topk(1, 1, True, True)
        return mcc_score(pred.view(-1), target)

# %%
class AverageMeter(object):
    """Computes and stores the average and current value"""

    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %% [markdown]
# ### Train dataset

# %%
def train(train_loader, model, criterion, optimizer, epoch):
    batch_time = AverageMeter()
    data_time = AverageMeter()
    losses = AverageMeter()
    mcc_meter = AverageMeter()  # Track MCC instead of accuracy

    # Switch to train mode
    model.train()

    end = time.time()
    for i, (input, target) in enumerate(train_loader):
        # Measure data loading time
        data_time.update(time.time() - end)

        if args.use_cuda:
            input = input.cuda(non_blocking=True)
            target = target.cuda(non_blocking=True)
            
        input = input.view(input.size(0), 42, -1)  # Reshape input
        
        # Compute output and loss
        output = model(input)
        loss = criterion(output, target)

        if args.clustering:
            loss += clustering_loss(model, args.lambda_coeff)

        # Compute MCC and record loss
        mcc_value = mcc(output.data, target)  # MCC calculation instead of topk accuracy
        losses.update(loss.item(), input.size(0))
        mcc_meter.update(mcc_value, input.size(0))

        # Compute gradient and do SGD step
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Measure elapsed time
        batch_time.update(time.time() - end)
        end = time.time()

    return mcc_meter.avg, losses.avg


def validate(val_loader, model, criterion, summary_output=True):
    losses = AverageMeter()
    mcc_meter = AverageMeter()
    acc_meter = AverageMeter()
    tpr_meter = AverageMeter()
    f1_meter = AverageMeter()

    # Chuyển model sang chế độ đánh giá
    model.eval()
    output_summary = []

    with torch.no_grad():
        for i, (input, target) in enumerate(test_loader):
            if input.size(1) == 42 and input.dim() == 2:  # Kiểm tra nếu thiếu chiều thứ 3
                input = input.unsqueeze(-1)

            if torch.cuda.is_available() and args.use_cuda:
                target = target.cuda(non_blocking=True)
                input = input.cuda(non_blocking=True)

            # Tính toán output và loss
            output = model(input)
            pred = torch.argmax(output, dim=1)  # Chọn nhãn dự đoán có xác suất cao nhất
            loss = criterion(output, target)
            losses.update(loss.item(), input.size(0))  # Cập nhật losses

            # Chuyển sang numpy để tính toán các chỉ số
            pred_np = pred.cpu().numpy()
            target_np = target.cpu().numpy()

            if summary_output:
                tmp_list = output.max(1, keepdim=True)[1].flatten().cpu().numpy() # get the index of the max log-probability
                output_summary.append(tmp_list)

            # Tính các chỉ số đánh giá
            mcc_value = matthews_corrcoef(target_np, pred_np)
            acc_value = accuracy_score(target_np, pred_np)
            tpr_value = recall_score(target_np, pred_np, average='macro')  # Macro recall ~ TPR
            f1_value = f1_score(target_np, pred_np, average='macro')

            # Cập nhật giá trị trung bình
            mcc_meter.update(mcc_value, input.size(0))
            acc_meter.update(acc_value, input.size(0))
            tpr_meter.update(tpr_value, input.size(0))
            f1_meter.update(f1_value, input.size(0))

    return mcc_meter.avg, acc_meter.avg, tpr_meter.avg, f1_meter.avg, losses.avg, output_summary

# %% [markdown]
# ### Validate

# %%
# def test( model, test_loader):
#     losses = AverageMeter()
#     mcc_meter = AverageMeter()  # Sử dụng MCC thay vì accuracy

#     with torch.no_grad():
#         for i, (input, target) in enumerate(test_loader):
#             if input.size(1) == 42 and input.dim() == 2:  # Kiểm tra nếu thiếu chiều thứ 3
#                 input = input.unsqueeze(-1)

#             if torch.cuda.is_available() and args.use_cuda:
#                 target = target.cuda(non_blocking=True)
#                 input = input.cuda(non_blocking=True)

#             # Tính toán output và loss
#             output = model(input)

                
#             # Tính MCC
#             mcc_value = mcc(output.data, target)
#             mcc_meter.update(mcc_value, input.size(0))

#     return mcc_meter.avg

from sklearn.metrics import matthews_corrcoef, accuracy_score, recall_score, f1_score
import warnings
from sklearn.exceptions import UndefinedMetricWarning

# Tắt cảnh báo UndefinedMetricWarning
warnings.filterwarnings("ignore", category=UndefinedMetricWarning)

def validate_score(model, test_loader):
    losses = AverageMeter()
    mcc_meter = AverageMeter()
    acc_meter = AverageMeter()
    tpr_meter = AverageMeter()
    f1_meter = AverageMeter()

    with torch.no_grad():
        for i, (input, target) in enumerate(test_loader):
            if input.size(1) == 42 and input.dim() == 2:  # Kiểm tra nếu thiếu chiều thứ 3
                input = input.unsqueeze(-1)

            if torch.cuda.is_available() and args.use_cuda:
                target = target.cuda(non_blocking=True)
                input = input.cuda(non_blocking=True)

            # Tính toán output và loss
            output = model(input)
            pred = torch.argmax(output, dim=1)  # Chọn nhãn dự đoán có xác suất cao nhất

            # Chuyển sang numpy để tính toán các chỉ số
            pred_np = pred.cpu().numpy()
            target_np = target.cpu().numpy()

            # Tính các chỉ số đánh giá
            mcc_value = matthews_corrcoef(target_np, pred_np)
            acc_value = accuracy_score(target_np, pred_np)
            tpr_value = recall_score(target_np, pred_np, average='macro')  # Macro recall ~ TPR
            f1_value = f1_score(target_np, pred_np, average='macro')

            # Cập nhật giá trị trung bình
            mcc_meter.update(mcc_value, input.size(0))
            acc_meter.update(acc_value, input.size(0))
            tpr_meter.update(tpr_value, input.size(0))
            f1_meter.update(f1_value, input.size(0))

    return {
        "MCC": mcc_meter.avg,
        "Accuracy": acc_meter.avg,
        "TPR": tpr_meter.avg,
        "F1 Score": f1_meter.avg
    }

# %% [markdown]
# ### class BFA

# %%
class BFA(object):
    def __init__(self, criterion, model, k_top=10):
        self.criterion = criterion
        self.loss_dict = {}
        self.bit_counter = 0
        self.k_top = k_top
        self.n_bits2flip = 0
        self.loss = 0
        self.num_bit_flipped = 0
        
        # Attributes for random attack
        self.module_list = []

        for name, m in model.named_modules():
            if isinstance(m, (quan_Conv1d, quan_Linear, CustomBlock)):
                self.module_list.append(name)

    def flip_bit(self, m):
        '''
        the data type of input param is 32-bit floating, then return the data should
        be in the same data_type.
        '''
        if self.k_top is None:
            k_top = m.weight.detach().flatten().__len__()
        else: 
            k_top = self.k_top
        # 1. flatten the gradient tensor to perform topk
        w_grad_topk, w_idx_topk = m.weight.grad.detach().abs().view(-1).topk(k_top)
        # update the b_grad to its signed representation
        w_grad_topk = m.weight.grad.detach().view(-1)[w_idx_topk]

        # 2. create the b_grad matrix in shape of [N_bits, k_top]
        b_grad_topk = w_grad_topk * m.b_w.data

        # 3. generate the gradient mask to zero-out the bit-gradient
        # which can not be flipped
        b_grad_topk_sign = (b_grad_topk.sign() +
                            1) * 0.5  # zero -> negative, one -> positive
        # convert to twos complement into unsigned integer
        w_bin = int2bin(m.weight.detach().view(-1), m.N_bits).short()
        w_bin_topk = w_bin[w_idx_topk]  # get the weights whose grads are topk
        
        # generate two's complement bit-map
        b_bin_topk = (w_bin_topk.repeat(m.N_bits, 1) & m.b_w.abs().repeat(1, k_top).short()) \
           // m.b_w.abs().repeat(1, k_top).short()

        grad_mask = b_bin_topk ^ b_grad_topk_sign.short()

        # 4. apply the gradient mask upon ```b_grad_topk``` and in-place update it
        b_grad_topk *= grad_mask.float()

        # 5. identify the several maximum of absolute bit gradient and return the index, the number of bits to flip is self.n_bits2flip

        grad_max = b_grad_topk.abs().max()
        num_elements = b_grad_topk.nelement()  # Get the total number of elements
        k = min(self.n_bits2flip, num_elements)  # Clamp the value of k
    
        _, b_grad_max_idx = b_grad_topk.abs().view(-1).topk(k)  # Use clamped k
        bit2flip = b_grad_topk.clone().view(-1).zero_()

        if grad_max.item() != 0:  # ensure the max grad is not zero
            bit2flip[b_grad_max_idx] = 1
            bit2flip = bit2flip.view(b_grad_topk.size())
        else:
            pass

        # 6. Based on the identified bit indexed by ```bit2flip```, generate another
        # mask, then perform the bitwise xor operation to realize the bit-flip.
        bit2flip = bit2flip.reshape(m.b_w.abs().shape[0], -1)  # Định hình lại

        w_bin_topk_flipped = (bit2flip.short() * m.b_w.abs().short()).sum(0, dtype=torch.int16) \
            ^ w_bin_topk

        # 7. update the weight in the original weight tensor
        w_bin[w_idx_topk] = w_bin_topk_flipped  # in-place change
        param_flipped = bin2int(w_bin,
                                m.N_bits).view(m.weight.data.size()).float()

        return param_flipped

    def progressive_bit_search(self, model, data, target, test_loader):
        ''' 
        Given the model, based on the current data and target, go through
        all the layers and identify the bits to be flipped. 
        '''
        model.eval()
        output = model(data)
        self.loss = self.criterion(output, target)
    
        # Zero out the grads first, then get the grads
        for m in model.modules():
            if isinstance(m, (quan_Conv1d, quan_Linear, CustomBlock)):
                if m.weight.grad is not None:
                    m.weight.grad.data.zero_()
    
        self.loss.backward()
        self.loss_max = self.loss.item()
        attack_log = []
        max_loss_module = None
    
        # 3. Flip bits until no further loss degradation is observed
        while self.loss_max <= self.loss.item():
            self.n_bits2flip += 1
            self.loss_dict = {}
    
            for name, module in model.named_modules():
                if isinstance(module, CustomBlock) or isinstance(module, quan_Conv1d):
                    clean_weight = module.weight.data.detach()
                    attack_weight = self.flip_bit(module)
                    self.num_bit_flipped += 1
    
                    module.weight.data = attack_weight
                    output = model(data)
    
                    self.loss_dict[name] = self.criterion(output, target).item()
                    module.weight.data = clean_weight
    
            # Check if loss_dict is not empty
            if not self.loss_dict:
                break
    
            max_loss_module = max(self.loss_dict.items(), key=lambda item: item[1])[0]
            self.loss_max = self.loss_dict[max_loss_module]
    
            if self.n_bits2flip == 100:
                break
    
        # Check if max_loss_module was never assigned
        if max_loss_module is None:
            attack_last_status = [self.bit_counter, "No module attacked", "No attack", "No attack"]
            return [], validate_score(model, test_loader), self.bit_counter, attack_last_status
    
        weight_prior = None
        weight_post = None
    
        # If loss_max does lead to degradation, change that layer's weight
        for module_idx, (name, module) in enumerate(model.named_modules()):
            if name == max_loss_module:
                attack_weight = self.flip_bit(module)
                self.num_bit_flipped += 1
    
                ###########################################################
                ## Attack profiling
                ##########################################################
                
                weight_mismatch = attack_weight - module.weight.detach()
                attack_weight_idx = torch.nonzero(weight_mismatch)
                print('attacked module:', max_loss_module)
                
                attack_log = []
                for i in range(attack_weight_idx.size(0)):
                    weight_idx = attack_weight_idx[i, :].cpu().numpy()
                    weight_prior = module.weight.detach()[tuple(weight_idx)].item()
                    weight_post = attack_weight[tuple(weight_idx)].item()
                
                    tmp_list = [module_idx, self.bit_counter + (i + 1), max_loss_module,
                                weight_idx, weight_prior, weight_post]
                    attack_log.append(tmp_list)
    
                module.weight.data = attack_weight
    
        self.bit_counter += self.n_bits2flip
        self.n_bits2flip = 0
    
        if weight_prior is None or weight_post is None:
            attack_last_status = [self.bit_counter, max_loss_module, "No attack", "No attack"]
        else:
            attack_last_status = [self.bit_counter, max_loss_module, weight_prior, weight_post]
        
        return attack_log, validate_score(model, test_loader), self.bit_counter, attack_last_status

    def random_flip_one_bit(self, model, test_loader):
        """
        Randomly flip one bit in the weight of a chosen module.
        """
        weight_prior = None
        weight_post = None
        
        chosen_module = random.choice(self.module_list)
        for name, m in model.named_modules():
            if name == chosen_module:
                flatten_weight = m.weight.detach().view(-1)
                chosen_idx = random.choice(range(flatten_weight.numel()))
                bin_w = int2bin(flatten_weight[chosen_idx], m.N_bits).short()
                bit_idx = random.choice(range(m.N_bits))
                mask = (bin_w.clone().zero_() + 1) * (2 ** bit_idx)
                bin_w = bin_w ^ mask
                int_w = bin2int(bin_w, m.N_bits).float()

                ##############################################
                ###   attack profiling
                ###############################################
                
                weight_mismatch = flatten_weight[chosen_idx] - int_w
                attack_weight_idx = chosen_idx

                print('attacked module:', chosen_module)
                
                attack_log = []
                weight_idx = chosen_idx
                weight_prior = flatten_weight[chosen_idx]
                weight_post = int_w

                print('attacked weight index:', weight_idx)
                print('weight before attack:', weight_prior)
                print('weight after attack:', weight_post)

                tmp_list = ["module_idx", self.bit_counter + 1, "loss",
                            weight_idx, weight_prior, weight_post]
                attack_log.append(tmp_list)                            

                self.bit_counter += 1
                flatten_weight[chosen_idx] = int_w
                m.weight.data = flatten_weight.view(m.weight.data.size())
                
        if weight_prior is None or weight_post is None:
            attack_last_status = [self.bit_counter, chosen_module, "No attack", "No attack"]
        else:
            attack_last_status = [self.bit_counter, chosen_module, weight_prior, weight_post]

        return attack_log, validate_score(model, test_loader), self.bit_counter, attack_last_status

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
net = CustomModel().to(device)

if args.use_cuda:
    if args.ngpu > 1:
        net = torch.nn.DataParallel(net, device_ids=list(range(args.ngpu)))
criterion = torch.nn.CrossEntropyLoss()
optimizer = optim.AdamW(net.parameters(), lr=0.001, weight_decay=0.01)
# optimizer = optim.Adam(net.parameters(), lr=0.001)

# separate the parameters thus param groups can be updated by different optimizer
all_param = [
    param for name, param in net.named_parameters()
    if not 'step_size' in name
]

step_param = [
    param for name, param in net.named_parameters() if 'step_size' in name 
]

if args.optimizer == "SGD":
    print("using SGD as optimizer")
    optimizer = torch.optim.SGD(all_param,
                                lr=0.01,
                                momentum=0.9,
                                weight_decay=0.0001,
                                nesterov=True)

elif args.optimizer == "Adam":
    print("using Adam as optimizer")
    optimizer = torch.optim.Adam(filter(lambda param: param.requires_grad,
                                        all_param),
                                 lr=0.001,
                                 #momentum=0.9,
                                 weight_decay=0.001)


elif args.optimizer == "RMSprop":
    print("using RMSprop as optimizer")
    optimizer = torch.optim.RMSprop(
        filter(lambda param: param.requires_grad, net.parameters()),
        lr=0.01,
        alpha=0.99,
        eps=1e-08,
        momentum=0.9,
        weight_decay=0.0001)
# Out:
# using SGD as optimizer

# %% [markdown]
# ## BFA Attack

# %%
if args.use_cuda:
    net.cuda()
    criterion.cuda()

if args.resume:
    if os.path.isfile(args.resume):
        checkpoint = torch.load(args.resume)
        if not args.fine_tune:
            args.start_epoch = checkpoint['epoch']
            recorder = checkpoint['recorder']
            optimizer.load_state_dict(checkpoint['optimizer'])

        state_tmp = net.state_dict()
        if 'state_dict' in checkpoint.keys():
            state_tmp.update(checkpoint['state_dict'])
        else:
            state_tmp.update(checkpoint)

        net.load_state_dict(state_tmp, strict=False)
    else:
        print("No checkpoint found at '{}'".format(args.resume))
else:
    print("Do not use any checkpoint for {} model".format(args.arch))


# Configure the quantization bit-width
if args.quan_bitwidth is not None:
    change_quan_bitwidth(net, args.quan_bitwidth)

# Update the step_size once the model is loaded. This is used for quantization.
for m in net.modules():
    if isinstance(m, quan_Conv1d) or isinstance(m, quan_Linear) or isinstance(m, CustomBlock) or m.__class__.__name__ == "CustomBlock" or m.__class__.__name__ == "quan_Conv1d":
        m.__reset_stepsize__()

# Block for weight reset
if args.reset_weight:
    for m in net.modules():
        if isinstance(m, quan_Conv1d) or isinstance(m, quan_Linear) or isinstance(m, CustomBlock):
            m.__reset_weight__()

attacker = BFA(criterion, net, args.k_top)  # Khởi tạo đối tượng tấn công
net_clean = copy.deepcopy(net)
    # weight_conversion(net)

if args.enable_bfa:
    perform_attack(attacker, net, net_clean, train_loader, test_loader,
                   args.n_iter, writer, csv_save_path=args.save_path,
                   random_attack=args.random_bfa)

if args.evaluate:
    print("Evaluate mode")
    _, _, _, output_summary = validate(test_loader, net, criterion, summary_output=True)
    pd.DataFrame(output_summary).to_csv(os.path.join(args.save_path, 'output_summary_{}.csv'.format(args.arch)),
                                        header=['top-1 output'], index=False)
# Out:
# No checkpoint found at 'save\model_best.pth.tar'
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')

# %%
def adjust_learning_rate(optimizer, epoch, gammas, schedule):
    """Sets the learning rate to the initial LR decayed by 10 every 30 epochs"""
    lr = args.learning_rate
    mu = args.momentum

    if args.optimizer != "YF":
        assert len(gammas) == len(
            schedule), "length of gammas and schedule should be equal"
        for (gamma, step) in zip(gammas, schedule):
            if (epoch >= step):
                lr = lr * gamma
            else:
                break
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr

    elif args.optimizer == "YF":
        lr = optimizer._lr
        mu = optimizer._mu

    return lr, mu

# %%
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
if args.ngpu == 1:
    os.environ["CUDA_VISIBLE_DEVICES"] = str(
        args.gpu_id)  # make only device #gpu_id visible, then

args.use_cuda = args.ngpu > 0 and torch.cuda.is_available()  # check GPU

# Give a random seed if no manual configuration
if args.manualSeed is None:
    args.manualSeed = random.randint(1, 10000)
random.seed(args.manualSeed)
torch.manual_seed(args.manualSeed)

if args.use_cuda:
    torch.cuda.manual_seed_all(args.manualSeed)

cudnn.benchmark = True

if args.use_cuda:
    print(f"Using GPU: {args.gpu_id} with seed: {args.manualSeed}")
else:
    print(f"Using CPU with seed: {args.manualSeed}")
# Out:
# Using GPU: 0 with seed: 8704

# %% [markdown]
# ### Hàm để train

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = CustomModel().to(device)
criterion = torch.nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters(), lr=0.001, weight_decay=0.01)

num_epochs = 20
patience = 10  
counter = 0

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5)

best_val_loss = float('inf')
best_mcc = -1 

for epoch in range(num_epochs):
    train_mcc, train_loss = train(train_loader, model, criterion, optimizer, epoch)

    val_mcc, val_acc, val_tpr, val_f1, val_loss, output_summary = validate(test_loader, model, criterion, summary_output=True)
    
    scheduler.step(val_loss)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_mcc = val_mcc
        counter = 0

        save_dir = "CustomModel"
        os.makedirs(save_dir, exist_ok=True)
        save_path = os.path.join(save_dir, "best_model.pth")

        torch.save(model.state_dict(), save_path)
    
    else:
        counter += 1
        if counter >= patience:
            print("Early stopping triggered")
            break

    print(f"Epoch {epoch+1}/{num_epochs}")
    print(f"Train Loss: {train_loss:.4f}, Train MCC: {train_mcc:.4f}")
    print(f"Validation Loss: {val_loss:.4f}, Validation MCC: {val_mcc:.4f}, ACC: {val_acc:.4f}, TPR: {val_tpr:.4f}, F1: {val_f1:.4f}")

print(f"Best MCC during training: {best_mcc:.4f}")
# Out:
# ' \ndevice = torch.device("cuda" if torch.cuda.is_available() else "cpu")\nmodel = CustomModel().to(device)\ncriterion = torch.nn.CrossEntropyLoss()\noptimizer = optim.AdamW(model.parameters(), lr=0.001, weight_decay=0.01)\n\nnum_epochs = 20\npatience = 10  \ncounter = 0\n\nscheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode=\'min\', factor=0.5, patience=5)\n\nbest_val_loss = float(\'inf\')\nbest_mcc = -1 \n\nfor epoch in range(num_epochs):\n    train_mcc, train_loss = train(train_loader, model, criterion, optimizer, epoch)\n\n    val_mcc, val_acc, val_tpr, val_f1, val_loss, output_summary = validate(test_loader, model, criterion, summary_output=True)\n    \n    scheduler.step(val_loss)\n\n    if val_loss < best_val_loss:\n        best_val_loss = val_loss\n        best_mcc = val_mcc\n        counter = 0\n\n        save_dir = "CustomModel"\n        os.makedirs(save_dir, exist_ok=True)\n        save_path = os.path.join(save_dir, "best_model.pth")\n\n        torch.save(model.state_dict(), save_path)\n    \n    else:\n        counter += 1\n        if counter >= patience:\n            print("Early stopping triggered")\n            break\n\n    print(f"Epoch {epoch+1}/{num_epochs}")\n    print(f"Train Loss: {train_loss:.4f}, Train MCC: {train_mcc:.4f}")\n    print(f"Validation Loss: {val_loss:.4f}, Validation MCC: {val_mcc:.4f}, ACC: {val_acc:.4f}, TPR: {val_tpr:.4f}, F1: {val_f1:.4f}")\n\nprint(f"Best MCC during training: {best_mcc:.4f}")\n'

# %% [markdown]
# ## Random Attack
#
# ### import data_conversion

# %%
def int2bin(input, num_bits):
    '''
    convert the signed integer value into unsigned integer (2's complement equivalently).
    Note that, the conversion is different depends on number of bit used.
    '''
    output = input.clone()
    if num_bits == 1: # when it is binary, the conversion is different
        output = output/2 + .5
    elif num_bits > 1:
        output[input.lt(0)] = 2**num_bits + output[input.lt(0)]

    return output


def bin2int(input, num_bits):
    '''
    convert the unsigned integer (2's complement equivantly) back to the signed integer format
    with the bitwise operations. Note that, in order to perform the bitwise operation, the input
    tensor has to be in the integer format.
    '''
    if num_bits == 1:
        output = input*2-1
    elif num_bits > 1:
        mask = 2**(num_bits - 1) - 1
        output = -(input & ~mask) + (input & mask)
    return output


def weight_conversion(model):
    '''
    Perform the weight data type conversion between:
        signed integer <==> two's complement (unsigned integer)
    Such conversion is used as additional step to ensure the conversion correctness

    Note that, the data type conversion chosen is depend on the bits:
        N_bits <= 8   .char()   --> torch.CharTensor(), 8-bit signed integer
        N_bits <= 16  .short()  --> torch.shortTensor(), 16 bit signed integer
        N_bits <= 32  .int()    --> torch.IntTensor(), 32 bit signed integer
    '''
    for m in model.modules():
        if isinstance(m, quan_Conv1d) or isinstance(m, quan_Linear):
            w_bin = int2bin(m.weight.data, m.N_bits).short()
            m.weight.data = bin2int(w_bin, m.N_bits).float()
    return

def count_ones(t, n_bits):
    counter = 0
    for i in range(n_bits):
        counter += ((t & 2**i) // 2**i).sum()
    return counter.item()


def hamming_distance(model1, model2):
    '''
    Given two model whose structure, name and so on are identical.
    The only difference between the model1 and model2 are the weight.
    The function compute the hamming distance bewtween the bianry weights
    (two's complement) of model1 and model2.
    '''
    # TODO: add the function check model1 and model2 are same structure
    # check the keys of state_dict match or not.

    H_dist = 0  # hamming distance counter

    for name, module in model1.named_modules():
        if isinstance(module, quan_Conv1d) or isinstance(module, quan_Linear):
            # remember to convert the tensor into integer for bitwise operations
            binW_model1 = int2bin(model1.state_dict()[name + '.weight'],
                                  module.N_bits).short()
            binW_model2 = int2bin(model2.state_dict()[name + '.weight'],
                                  module.N_bits).short()
            H_dist += count_ones(binW_model1 ^ binW_model2, module.N_bits)

    return H_dist

# %% [markdown]
# ## Vẽ đồ thị MCC sau mỗi epoch

# %%
import matplotlib.pyplot as plt

def plot_mcc_vs_epoch(images_filename, x_data, y_data):
    titles = ["MCC", "ACC", "TPR", "F1-Score"]
    
    for image_filename, title in zip(images_filename, titles):
        if len(x_data) != len(y_data):
            raise ValueError("x_data and y_data must have the same length.")
    
        plt.figure(figsize=(10, 6))
        plt.plot(x_data, y_data, marker='o', linestyle='-', color='b', label='MCC')
        plt.title(f'{title} after Epochs', fontsize=14) 
        plt.xlabel('Epoch', fontsize=12)
        plt.ylabel(title, fontsize=12)
        
        plt.grid(True, linestyle='--', alpha=0.7)
        plt.legend()
        plt.tight_layout()

        min_x, max_x = min(x_data), max(x_data)
        plt.xticks(range(min_x, max_x + 1, 2))
        
        # Save the plot as an image file
        plt.savefig(image_filename)
        plt.close()
        print(f"Plot saved as {image_filename}")

def plot_combined_metrics(image_filename, x_data, metric_dict):
    colors = {
        "MCC": "blue",
        "ACC": "orange",
        "TPR": "green",
        "F1": "red"
    }

    plt.figure(figsize=(10, 6))
    for metric in ["MCC", "ACC", "TPR", "F1"]:
        y = [float(v) for v in metric_dict[metric]]
        plt.plot(x_data, y, label=metric, color=colors[metric], linewidth=2)
        plt.fill_between(x_data,
                         [v * 0.95 for v in y],
                         [v * 1.05 for v in y],
                         alpha=0.2, color=colors[metric])

    plt.xlabel("Epoch", fontsize=12)
    plt.ylabel("Metric Value (%)", fontsize=12)
    plt.title("Combined Metrics during Attack", fontsize=14)
    plt.legend()
    plt.grid(True, linestyle="--", alpha=0.7)
    plt.tight_layout()
    plt.savefig(image_filename)
    plt.close()
    print(f"[Combined Plot] Saved as {image_filename}")

# %%
# import csv
# def perform_attack(attacker, model, model_clean, train_loader, test_loader,
#                    N_iter, writer, file, csv_file, csv_save_path=None, attack_type=1,):
#     model.eval()
#     losses = AverageMeter()
#     iter_time = AverageMeter()
#     attack_time = AverageMeter()

#     for _, (data, target) in enumerate(train_loader):
#         if args.use_cuda:
#             target = target.cuda()
#             data = data.cuda()

#         data = data.unsqueeze(-1)  # Kích thước [512, 42, 1]
#         _, target = model(data).data.max(1)
#         break

#     val_acc_top1, val_loss, output_summary = validate(test_loader, model, attacker.criterion, summary_output=True)
#     print(f'**Test** MCC: {val_acc_top1:.3f}. Val_Loss: {val_loss:.3f}')

#     tmp_df = pd.DataFrame(output_summary)
#     tmp_df['BFA iteration'] = 0
#     tmp_df.to_csv(os.path.join(args.save_path, 'output_summary_{}_BFA_0.csv'.format(args.arch)), index=False)

#     writer.add_scalar('attack/val_top1_acc', val_acc_top1, 0)
#     writer.add_scalar('attack/val_loss', val_loss, 0)

#     print('Attack sample size is {}'.format(data.size()[0]))
#     end = time.time()
#     df = pd.DataFrame()
#     last_val_acc_top1 = val_acc_top1

#     MCC_data = [val_acc_top1]
#     epochs = [0]
#     all_attack_status = []

#     for i_iter in range(N_iter):
#         print('**********************************')        
#         if attack_type == 1:
#             attack_log, new_mcc, bit_count, attack_last_status = attacker.progressive_bit_search(model, data, target, test_loader)
#             MCC_data.append(new_mcc)
#             epochs.append(bit_count)
#         elif attack_type == 2:
#             attack_log, new_mcc, bit_count, attack_last_status = attacker.random_flip_one_bit(model, test_loader)
#             MCC_data.append(new_mcc)
#             epochs.append(bit_count)
#         elif attack_type == 3:
#             attack_log, new_mcc, bit_count, attack_last_status = attacker.progressive_bit_search(model, data, target, test_loader)
#             attack_log, new_mcc, bit_count, attack_last_status = attacker.random_flip_one_bit(model, test_loader)
#             MCC_data.append(new_mcc)
#             epochs.append(bit_count)
#         elif attack_type == 4:
#             attack_log, new_mcc, bit_count, attack_last_status = attacker.random_flip_one_bit(model, test_loader)
#             attack_log, new_mcc, bit_count, attack_last_status = attacker.progressive_bit_search(model, data, target, test_loader)
#             MCC_data.append(new_mcc)
#             epochs.append(bit_count)
        
#         attack_time.update(time.time() - end)
#         end = time.time()

#         h_dist = hamming_distance(model, model_clean)

#         if hasattr(attacker, "loss_max"):
#             losses.update(attacker.loss_max, data.size(0))

#         print('Iteration: [{:03d}/{:03d}]   Attack Time {attack_time.val:.3f} ({attack_time.avg:.3f})'.format(i_iter + 1, N_iter, attack_time=attack_time))

#         try:
#             print('Loss before attack: {:.4f}'.format(attacker.loss.item()))
#             print('Loss after attack: {:.4f}'.format(attacker.loss_max))
#         except:
#             pass

#         print('Bit flips: {:.0f}'.format(attacker.bit_counter))
#         print('Hamming distance: {:.0f}'.format(h_dist))

#         writer.add_scalar('attack/bit_flip', attacker.bit_counter, i_iter + 1)
#         writer.add_scalar('attack/h_dist', h_dist, i_iter + 1)
#         writer.add_scalar('attack/sample_loss', losses.avg, i_iter + 1)

#         val_acc_top1, val_loss, output_summary = validate(test_loader, model, attacker.criterion, summary_output=True)
#         print(f'**Test** MCC: {val_acc_top1:.3f}. Val_Loss: {val_loss:.3f}')
#         tmp_df = pd.DataFrame(output_summary)
#         tmp_df['BFA iteration'] = i_iter + 1
#         tmp_df.to_csv(os.path.join(args.save_path, 'output_summary_{}_BFA_{}.csv'.format(args.arch, i_iter + 1)), index=False)

#         acc_drop = last_val_acc_top1 - val_acc_top1
#         last_val_acc_top1 = val_acc_top1

#         attack_last_status.append(val_acc_top1)
#         attack_last_status.append(acc_drop)

#         for entry in attack_log:
#             entry.append(val_acc_top1)
#             entry.append(acc_drop)
            
#         df = pd.concat([df, pd.DataFrame(attack_log)], ignore_index=True)

#         writer.add_scalar('attack/val_top1_acc', val_acc_top1, i_iter + 1)
#         writer.add_scalar('attack/val_loss', val_loss, i_iter + 1)

#         iter_time.update(time.time() - end)
#         print('Iteration Time {iter_time.val:.3f} ({iter_time.avg:.3f})'.format(iter_time=iter_time))
#         end = time.time()

#         all_attack_status.append(attack_last_status)

#     column_list = ['module idx', 'bit-flip idx', 'module name', 'weight idx', 'weight before attack', 'weight after attack', 'validation mcc', 'mcc drop']
#     df.columns = column_list
#     df['trial seed'] = args.manualSeed

#     if csv_save_path is not None:
#         csv_file_name = 'attack_profile_{}.csv'.format(args.manualSeed)
#         df.to_csv(os.path.join(csv_save_path, csv_file_name), index=None)

#     # Vẽ đồ thị
#     plot_mcc_vs_epoch(file, epochs, MCC_data)
    
#     with open(csv_file, mode='w', newline='') as file:
#         writer = csv.writer(file)
        
#         # Ghi tiêu đề (nếu cần)
#         writer.writerow(["Bit Counter", "Module", "Weight Before Attack", "Weight After Attack", "Validation", "MCC Drop"])
        
#         # Ghi dữ liệu
#         writer.writerows(all_attack_status)
    
#     return

# %%
import csv
def perform_attack(attacker, model, model_clean, train_loader, test_loader,
                   N_iter, writer, file, csv_file, csv_save_path=None, attack_type=1,):
    model.eval()
    losses = AverageMeter()
    iter_time = AverageMeter()
    attack_time = AverageMeter()

    for _, (data, target) in enumerate(train_loader):
        if args.use_cuda:
            target = target.cuda()
            data = data.cuda()

        data = data.unsqueeze(-1)  # Kích thước [512, 39, 1]
        _, target = model(data).data.max(1)
        break

    val_mcc_top1, val_acc_top1, val_tpr_top1, val_f1score_top1, val_loss, output_summary = validate(test_loader, model, attacker.criterion, summary_output=True)
    print(f'**Test** MCC: {val_mcc_top1:.3f}. Val_Loss: {val_loss:.3f}')
    print(f'ACC: {val_acc_top1:.3f}.')
    print(f'TPR: {val_tpr_top1:.3f}.')
    print(f'F1-score: {val_f1score_top1:.3f}.')

    tmp_df = pd.DataFrame(output_summary)
    tmp_df['BFA iteration'] = 0
    tmp_df.to_csv(os.path.join(args.save_path, 'output_summary_{}_BFA_0.csv'.format(args.arch)), index=False)

    writer.add_scalar('attack/val_top1_acc', val_mcc_top1, 0)
    writer.add_scalar('attack/val_loss', val_loss, 0)

    print('Attack sample size is {}'.format(data.size()[0]))
    end = time.time()
    df = pd.DataFrame()
    last_val_mcc_top1 = val_mcc_top1
    last_val_acc_top1 = val_acc_top1
    last_val_tpr_top1 = val_tpr_top1
    last_val_f1score_top1 = val_f1score_top1

    MCC_data = [val_mcc_top1]
    epochs = [0]
    all_attack_status = []
    
    metric_dict = {
            "MCC": [val_mcc_top1],
            "ACC": [val_acc_top1],
            "TPR": [val_tpr_top1],
            "F1": [val_f1score_top1]
        }
    
    for i_iter in range(N_iter):
        print('**********************************')        
        if attack_type == 1:
            attack_log, new_mcc, bit_count, attack_last_status = attacker.progressive_bit_search(model, data, target, test_loader)
            MCC_data.append(new_mcc['MCC'])
            epochs.append(i_iter)
        elif attack_type == 2:
            attack_log, new_mcc, bit_count, attack_last_status = attacker.random_flip_one_bit(model, test_loader)
            MCC_data.append(new_mcc['MCC'])
            epochs.append(i_iter)
        elif attack_type == 3:
            attack_log, new_mcc, bit_count, attack_last_status = attacker.progressive_bit_search(model, data, target, test_loader)
            attack_log, new_mcc, bit_count, attack_last_status = attacker.random_flip_one_bit(model, test_loader)
            MCC_data.append(new_mcc['MCC'])
            epochs.append(i_iter)
        elif attack_type == 4:
            attack_log, new_mcc, bit_count, attack_last_status = attacker.random_flip_one_bit(model, test_loader)
            attack_log, new_mcc, bit_count, attack_last_status = attacker.progressive_bit_search(model, data, target, test_loader)
            MCC_data.append(new_mcc['MCC'])
            epochs.append(i_iter)
            
        metric_dict["MCC"].append(new_mcc["MCC"])
        metric_dict["ACC"].append(new_mcc["Accuracy"])
        metric_dict["TPR"].append(new_mcc["TPR"])
        metric_dict["F1"].append(new_mcc["F1 Score"])
        
        attack_time.update(time.time() - end)
        end = time.time()

        h_dist = hamming_distance(model, model_clean)

        if hasattr(attacker, "loss_max"):
            losses.update(attacker.loss_max, data.size(0))

        print('Iteration: [{:03d}/{:03d}]   Attack Time {attack_time.val:.3f} ({attack_time.avg:.3f})'.format(i_iter + 1, N_iter, attack_time=attack_time))

        try:
            print('Loss before attack: {:.4f}'.format(attacker.loss.item()))
            print('Loss after attack: {:.4f}'.format(attacker.loss_max))
        except:
            pass

        print('Bit flips: {:.0f}'.format(attacker.bit_counter))
        print('Hamming distance: {:.0f}'.format(h_dist))

        writer.add_scalar('attack/bit_flip', attacker.bit_counter, i_iter + 1)
        writer.add_scalar('attack/h_dist', h_dist, i_iter + 1)
        writer.add_scalar('attack/sample_loss', losses.avg, i_iter + 1)

        val_mcc_top1, val_acc_top1, val_tpr_top1, val_f1score_top1, val_loss, output_summary = validate(test_loader, model, attacker.criterion, summary_output=True)
        print(f'**Test** MCC: {val_mcc_top1:.3f}. Val_Loss: {val_loss:.3f}')
        print(f'ACC: {val_acc_top1:.3f}.')
        print(f'TPR: {val_tpr_top1:.3f}.')
        print(f'F1-score: {val_f1score_top1:.3f}.')
        
        tmp_df = pd.DataFrame(output_summary)
        tmp_df['BFA iteration'] = i_iter + 1
        tmp_df.to_csv(os.path.join(args.save_path, 'output_summary_{}_BFA_{}.csv'.format(args.arch, i_iter + 1)), index=False)

        # last_val_mcc_top1 = val_mcc_top1
        # last_val_acc_top1 = val_acc_top1
        # last_val_tpr_top1 = val_tpr_top1
        # last_val_f1score_top1 = val_f1score_top1
        
        mcc_drop = last_val_mcc_top1 - val_mcc_top1
        last_val_mcc_top1 = val_mcc_top1

        acc_drop = last_val_acc_top1 - val_acc_top1
        last_val_acc_top1 = val_acc_top1

        tpr_drop = last_val_tpr_top1 - val_tpr_top1
        last_val_tpr_top1 = val_tpr_top1

        f1score_drop = last_val_f1score_top1 - val_f1score_top1
        last_val_f1score_top1 = val_f1score_top1

        attack_last_status.append(round(val_mcc_top1, 5))
        attack_last_status.append(round(mcc_drop, 5))
        
        attack_last_status.append(round(val_acc_top1, 5))
        attack_last_status.append(round(acc_drop, 5))
        
        attack_last_status.append(round(val_tpr_top1, 5))
        attack_last_status.append(round(tpr_drop, 5))
        
        attack_last_status.append(round(val_f1score_top1, 5))
        attack_last_status.append(round(f1score_drop, 5))

        for entry in attack_log:
            entry.append(val_mcc_top1)
            entry.append(mcc_drop)

            entry.append(val_acc_top1)
            entry.append(acc_drop)

            entry.append(val_tpr_top1)
            entry.append(tpr_drop)

            entry.append(val_f1score_top1)
            entry.append(f1score_drop)
            
        df = pd.concat([df, pd.DataFrame(attack_log)], ignore_index=True)

        writer.add_scalar('attack/val_top1_acc', val_mcc_top1, i_iter + 1)
        writer.add_scalar('attack/val_loss', val_loss, i_iter + 1)

        iter_time.update(time.time() - end)
        print('Iteration Time {iter_time.val:.3f} ({iter_time.avg:.3f})'.format(iter_time=iter_time))
        end = time.time()

        all_attack_status.append(attack_last_status)

    column_list = ['module idx', 'bit-flip idx', 'module name', 'weight idx', 'weight before attack', 'weight after attack'
                    , 'validation mcc', 'mcc drop'
                    , "ACC", "ACC Drop"
                    , "TPR", "TPR Drop"
                    , "F1-score", "F1-score Drop",]
    df.columns = column_list
    df['trial seed'] = args.manualSeed

    if csv_save_path is not None:
        csv_file_name = 'attack_profile_{}.csv'.format(args.manualSeed)
        df.to_csv(os.path.join(csv_save_path, csv_file_name), index=None)
        
    # Vẽ đồ thị với MCC
    plot_mcc_vs_epoch(file, epochs, MCC_data)
    
    try:
        if isinstance(file, list) and len(file) > 0:
            first_image_name = os.path.basename(file[0])
            suffix = first_image_name.split("_", 1)[-1] if "_" in first_image_name else "attack.png"
            combined_plot_path = os.path.join(os.path.dirname(file[0]), f"combined_metrics_{suffix}")
        else:
            combined_plot_path = "combined_metrics.png"

        plot_combined_metrics(combined_plot_path, epochs, metric_dict)
    except Exception as e:
        print(f"[Warning] Plotting combined metrics failed: {e}")
        
    with open(csv_file, mode='w', newline='') as file:
        writer = csv.writer(file)
        
        # Ghi tiêu đề (nếu cần)
        writer.writerow(["Bit Counter", "Module", "Weight Before Attack", "Weight After Attack"
                         , "MCC", "MCC Drop"
                         , "ACC", "ACC Drop"
                         , "TPR", "TPR Drop"
                         , "F1-score", "F1-score Drop",])
        
        # Ghi dữ liệu
        writer.writerows(all_attack_status)
    
    return

# %%
# Bước 1: Tải mô hình đã huấn luyện
model_path = os.path.join("CustomModel", "best_model.pth")
# Kiểm tra xem tệp có tồn tại không
if not os.path.exists(model_path):
    raise FileNotFoundError(f"Không tìm thấy mô hình tại: {model_path}")

trained_model = CustomModel()

# Tải trọng số từ file best_model.pth
trained_model.load_state_dict(torch.load(model_path, map_location=torch.device('cuda' if torch.cuda.is_available() else 'cpu')))
trained_model = trained_model.to(device)

results = validate_score(trained_model, test_loader)
print(f"MCC before attack: {results['MCC']}")
print(f"Accuracy before attack: {results['Accuracy']}")
print(f"TPR before attack: {results['TPR']}")
print(f"F1-score before attack: {results['F1 Score']}")
# Out:
# MCC before attack: 0.9979121278157115
# Accuracy before attack: 0.9997
# TPR before attack: 0.9861050267205141
# F1-score before attack: 0.9855526760216656

# %%
# Bước 2: Tạo bản sao của mô hình để làm tham chiếu
model_clean = copy.deepcopy(trained_model)

# Bước 3: Khởi tạo đối tượng tấn công BFA
attacker = BFA(criterion=criterion, model=trained_model, k_top=10)

# Định nghĩa đường dẫn để lưu kết quả tấn công
attack_dir = os.path.join("CustomModel", "PBS_attack")

os.makedirs(attack_dir, exist_ok=True)
attack_image_paths = [os.path.join(attack_dir, f"{metric}_PBS_attack.png") 
                      for metric in ["MCC", "ACC", "TPR", "F1"]]
# attack_image_path = os.path.join(attack_dir, "PBS_attack.png")
attack_csv_path = os.path.join(attack_dir, "PBS_attack.csv")

# Bước 4: Thực hiện tấn công
perform_attack(
    attacker=attacker,               # Đối tượng tấn công
    model=trained_model,             # Mô hình bị tấn công
    model_clean=model_clean,         # Mô hình gốc làm tham chiếu
    train_loader=train_loader,       # Bộ dữ liệu huấn luyện
    test_loader=test_loader,         # Bộ dữ liệu kiểm tra
    N_iter=args.n_iter,              # Số vòng lặp tấn công
    writer=writer,                   # TensorBoard writer để ghi log
    file=attack_image_paths,          # Lưu ảnh vào thư mục tấn công
    csv_file=attack_csv_path, 
    csv_save_path=args.save_path,    # Đường dẫn lưu file CSV
    attack_type= 1,                  # Chế độ tấn công PBS
)

writer.close()  # Đóng TensorBoard writer
# best_mcc = validate_score(trained_model, test_loader)
# print(f"\nMCC after 100 times PBS attack: {best_mcc}")

results = validate_score(trained_model, test_loader)
print(f"MCC after 100 times PBS attack: {results['MCC']}")
print(f"Accuracy after 100 times PBS attack: {results['Accuracy']}")
print(f"TPR after 100 times PBS attack: {results['TPR']}")
print(f"F1-score after 100 times PBS attack: {results['F1 Score']}")
# Out:
# **Test** MCC: 0.999. Val_Loss: 0.005
# ACC: 1.000.
# TPR: 0.987.
# F1-score: 0.986.
# Attack sample size is 256
# **********************************
# attacked module: fc1
# Iteration: [001/025]   Attack Time 9.824 (9.824)
# Loss before attack: 0.0000
# Loss after attack: 24.6649
# Bit flips: 1
# Hamming distance: 1
# **Test** MCC: -0.258. Val_Loss: 24.647
# ACC: 0.021.
# TPR: 0.088.
# F1-score: 0.099.
# Iteration Time 9.091 (9.091)
# **********************************
# attacked module: stage_1.3.conv_b
# Iteration: [002/025]   Attack Time 9.684 (9.754)
# Loss before attack: 24.6649
# Loss after attack: 850.1472
# Bit flips: 2
# Hamming distance: 2
# **Test** MCC: -0.199. Val_Loss: 859.251
# ACC: 0.006.
# TPR: 0.131.
# F1-score: 0.004.
# Iteration Time 8.819 (8.955)
# **********************************
# attacked module: stage_1.3.conv_a
# Iteration: [003/025]   Attack Time 10.607 (10.038)
# Loss before attack: 850.1472
# Loss after attack: 108412.6562
# Bit flips: 3
# Hamming distance: 3
# **Test** MCC: -0.297. Val_Loss: 109065.853
# ACC: 0.003.
# TPR: 0.105.
# F1-score: 0.004.
# Iteration Time 8.983 (8.964)
# **********************************
# attacked module: stage_1.0.conv_b
# Iteration: [004/025]   Attack Time 9.768 (9.971)
# Loss before attack: 108412.6562
# Loss after attack: 2066949.1250
# Bit flips: 4
# Hamming distance: 4
# **Test** MCC: -0.186. Val_Loss: 2091123.109
# ACC: 0.005.
# TPR: 0.103.
# F1-score: 0.003.
# Iteration Time 8.874 (8.942)
# **********************************
# attacked module: stage_1.0.conv_a
# Iteration: [005/025]   Attack Time 9.804 (9.937)
# Loss before attack: 2066949.1250
# Loss after attack: 1164401792.0000
# Bit flips: 5
# Hamming distance: 5
# **Test** MCC: -0.245. Val_Loss: 1168912877.188
# ACC: 0.003.
# TPR: 0.109.
# F1-score: 0.004.
# Iteration Time 8.831 (8.919)
# **********************************
# attacked module: stage_1.1.conv_b
# Iteration: [006/025]   Attack Time 9.846 (9.922)
# Loss before attack: 1164401792.0000
# Loss after attack: 27476514816.0000
# Bit flips: 6
# Hamming distance: 6
# **Test** MCC: -0.211. Val_Loss: 27583297670.817
# ACC: 0.003.
# TPR: 0.110.
# F1-score: 0.002.
# Iteration Time 9.199 (8.966)
# **********************************
# attacked module: stage_1.1.conv_a
# Iteration: [007/025]   Attack Time 9.492 (9.861)
# Loss before attack: 27476514816.0000
# Loss after attack: 9164665389056.0000
# Bit flips: 7
# Hamming distance: 7
# **Test** MCC: -0.234. Val_Loss: 9200407206436.162
# ACC: 0.003.
# TPR: 0.115.
# F1-score: 0.005.
# Iteration Time 8.857 (8.950)
# **********************************
# attacked module: stage_3.4.conv_a
# Iteration: [008/025]   Attack Time 13.949 (10.372)
# Loss before attack: 9164665389056.0000
# Loss after attack: 112074621452288.0000
# Bit flips: 8
# Hamming distance: 8
# **Test** MCC: -0.234. Val_Loss: 112512153039891.891
# ACC: 0.003.
# TPR: 0.115.
# F1-score: 0.004.
# Iteration Time 9.225 (8.985)
# **********************************
# attacked module: stage_2.15.conv_b
# Iteration: [009/025]   Attack Time 10.302 (10.364)
# Loss before attack: 112074621452288.0000
# Loss after attack: 1713107567116288.0000
# Bit flips: 9
# Hamming distance: 9
# **Test** MCC: -0.131. Val_Loss: 1719743110156918.000
# ACC: 0.005.
# TPR: 0.177.
# F1-score: 0.004.
# Iteration Time 8.974 (8.984)
# **********************************
# attacked module: stage_2.15.conv_a
# Iteration: [010/025]   Attack Time 10.407 (10.368)
# Loss before attack: 1713107567116288.0000
# Loss after attack: 277605365795782656.0000
# Bit flips: 10
# Hamming distance: 10
# **Test** MCC: -0.234. Val_Loss: 278688921770255168.000
# ACC: 0.003.
# TPR: 0.115.
# F1-score: 0.004.
# Iteration Time 8.926 (8.978)
# **********************************
# attacked module: stage_1.7.conv_b
# Iteration: [011/025]   Attack Time 9.425 (10.283)
# Loss before attack: 277605365795782656.0000
# Loss after attack: 3389379557671829504.0000
# Bit flips: 11
# Hamming distance: 11
# **Test** MCC: -0.233. Val_Loss: 3402798612047134720.000
# ACC: 0.003.
# TPR: 0.115.
# F1-score: 0.002.
# Iteration Time 9.014 (8.981)
# **********************************
# attacked module: stage_1.7.conv_a
# Iteration: [012/025]   Attack Time 9.564 (10.223)
# Loss before attack: 3389379557671829504.0000
# Loss after attack: 430752521412501569536.0000
# Bit flips: 12
# Hamming distance: 12
# **Test** MCC: -0.231. Val_Loss: 432451685617685692416.000
# ACC: 0.003.
# TPR: 0.121.
# F1-score: 0.003.
# Iteration Time 8.937 (8.977)
# **********************************
# attacked module: stage_1.14.conv_a
# Iteration: [013/025]   Attack Time 9.587 (10.174)
# Loss before attack: 430752521412501569536.0000
# Loss after attack: 4813202398503847854080.0000
# Bit flips: 13
# Hamming distance: 13
# **Test** MCC: -0.231. Val_Loss: 4831976583350853828608.000
# ACC: 0.003.
# TPR: 0.121.
# F1-score: 0.003.
# Iteration Time 9.199 (8.994)
# **********************************
# attacked module: stage_1.14.conv_b
# Iteration: [014/025]   Attack Time 9.918 (10.156)
# Loss before attack: 4813202398503847854080.0000
# Loss after attack: 1664851655030356404338688.0000
# Bit flips: 14
# Hamming distance: 14
# **Test** MCC: -0.231. Val_Loss: 1671318429532580957126656.000
# ACC: 0.003.
# TPR: 0.121.
# F1-score: 0.003.
# Iteration Time 9.187 (9.008)
# **********************************
# attacked module: stage_3.5.conv_b
# Iteration: [015/025]   Attack Time 13.538 (10.381)
# Loss before attack: 1664851655030356404338688.0000
# Loss after attack: 17702999022773693059170304.0000
# Bit flips: 15
# Hamming distance: 15
# **Test** MCC: -0.231. Val_Loss: 17771355010398967090380800.000
# ACC: 0.003.
# TPR: 0.121.
# F1-score: 0.003.
# Iteration Time 9.052 (9.011)
# **********************************
# attacked module: stage_3.5.conv_a
# Iteration: [016/025]   Attack Time 13.560 (10.580)
# Loss before attack: 17702999022773693059170304.0000
# Loss after attack: 2571325303295564845976387584.0000
# Bit flips: 16
# Hamming distance: 16
# **Test** MCC: -0.046. Val_Loss: 2581434722701319189422931968.000
# ACC: 0.007.
# TPR: 0.255.
# F1-score: 0.005.
# Iteration Time 8.968 (9.008)
# **********************************
# attacked module: stage_3.4.conv_b
# Iteration: [017/025]   Attack Time 13.209 (10.734)
# Loss before attack: 2571325303295564845976387584.0000
# Loss after attack: 440277523098564047464229240832.0000
# Bit flips: 17
# Hamming distance: 17
# **Test** MCC: -0.046. Val_Loss: 441991309889054137186988851200.000
# ACC: 0.007.
# TPR: 0.255.
# F1-score: 0.005.
# Iteration Time 9.154 (9.017)
# **********************************
# attacked module: stage_3.12.conv_a
# Iteration: [018/025]   Attack Time 13.691 (10.899)
# Loss before attack: 440277523098564047464229240832.0000
# Loss after attack: 6044291807769473391991136976896.0000
# Bit flips: 18
# Hamming distance: 18
# **Test** MCC: -0.039. Val_Loss: 6067621259774446575194183041024.000
# ACC: 0.000.
# TPR: 0.014.
# F1-score: 0.001.
# Iteration Time 9.309 (9.033)
# **********************************
# attacked module: stage_3.12.conv_b
# Iteration: [019/025]   Attack Time 13.624 (11.042)
# Loss before attack: 6044291807769473391991136976896.0000
# Loss after attack: 898276681928841116505386680057856.0000
# Bit flips: 19
# Hamming distance: 19
# **Test** MCC: -0.039. Val_Loss: 901740057439144970686481840472064.000
# ACC: 0.000.
# TPR: 0.014.
# F1-score: 0.001.
# Iteration Time 9.186 (9.041)
# **********************************
# attacked module: stage_1.4.conv_b
# Iteration: [020/025]   Attack Time 9.810 (10.980)
# Loss before attack: 898276681928841116505386680057856.0000
# Loss after attack: 9306037219902228407174855779155968.0000
# Bit flips: 20
# Hamming distance: 20
# **Test** MCC: 0.000. Val_Loss: 9342288526881718879661099843584000.000
# ACC: 0.000.
# TPR: 0.016.
# F1-score: 0.000.
# Iteration Time 9.041 (9.041)
# **********************************
# attacked module: stage_1.4.conv_a
# Iteration: [021/025]   Attack Time 9.620 (10.916)
# Loss before attack: 9306037219902228407174855779155968.0000
# Loss after attack: inf
# Bit flips: 21
# Hamming distance: 21
# **Test** MCC: -0.058. Val_Loss: inf
# ACC: 0.000.
# TPR: 0.011.
# F1-score: 0.000.
# Iteration Time 9.006 (9.039)
# **********************************
# attacked module: fc1
# Iteration: [022/025]   Attack Time 25.308 (11.570)
# Loss before attack: inf
# Loss after attack: nan
# Bit flips: 35
# Hamming distance: 35
# **Test** MCC: -0.028. Val_Loss: nan
# ACC: 0.005.
# TPR: 0.015.
# F1-score: 0.004.
# Iteration Time 9.001 (9.038)
# **********************************
# Iteration: [023/025]   Attack Time 8.248 (11.425)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 35
# Hamming distance: 35
# **Test** MCC: -0.028. Val_Loss: nan
# ACC: 0.005.
# TPR: 0.015.
# F1-score: 0.004.
# Iteration Time 9.140 (9.042)
# **********************************
# Iteration: [024/025]   Attack Time 8.055 (11.285)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 35
# Hamming distance: 35
# **Test** MCC: -0.028. Val_Loss: nan
# ACC: 0.005.
# TPR: 0.015.
# F1-score: 0.004.
# Iteration Time 9.200 (9.049)
# **********************************
# Iteration: [025/025]   Attack Time 8.186 (11.161)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 35
# Hamming distance: 35
# **Test** MCC: -0.028. Val_Loss: nan
# ACC: 0.005.
# TPR: 0.015.
# F1-score: 0.004.
# Iteration Time 9.136 (9.052)
# Plot saved as CustomModel/PBS_attack/MCC_PBS_attack.png
# Plot saved as CustomModel/PBS_attack/ACC_PBS_attack.png
# Plot saved as CustomModel/PBS_attack/TPR_PBS_attack.png
# Plot saved as CustomModel/PBS_attack/F1_PBS_attack.png
# [Combined Plot] Saved as CustomModel/PBS_attack/combined_metrics_PBS_attack.png
# MCC after 100 times PBS attack: -0.027916698633516316
# Accuracy after 100 times PBS attack: 0.005285714285714286
# TPR after 100 times PBS attack: 0.01473112096021739
# F1-score after 100 times PBS attack: 0.0040028303838408

# %%
# Bước 1: Tải mô hình đã huấn luyện
model_path = os.path.join("CustomModel", "best_model.pth")

trained_model = CustomModel()

# Tải trọng số từ file best_model.pth
trained_model.load_state_dict(torch.load(model_path, map_location=torch.device('cuda' if torch.cuda.is_available() else 'cpu')))
trained_model = trained_model.to(device)

# Bước 2: Tạo bản sao của mô hình để làm tham chiếu
model_clean = copy.deepcopy(trained_model)

# Bước 3: Khởi tạo đối tượng tấn công BFA
attacker = BFA(criterion=criterion, model=trained_model, k_top=10)

# Định nghĩa đường dẫn để lưu kết quả tấn công
attack_dir = os.path.join("CustomModel", "RandomFlip_attack")

os.makedirs(attack_dir, exist_ok=True)
attack_image_paths = [os.path.join(attack_dir, f"{metric}_RandomFlip_attack.png") 
                      for metric in ["MCC", "ACC", "TPR", "F1"]]
# attack_image_path = os.path.join(attack_dir, "RandomFlip_attack.png")
attack_csv_path = os.path.join(attack_dir, "RandomFlip_attack.csv")

# Bước 4: Thực hiện tấn công
perform_attack(
    attacker=attacker,               # Đối tượng tấn công
    model=trained_model,             # Mô hình bị tấn công
    model_clean=model_clean,         # Mô hình gốc làm tham chiếu
    train_loader=train_loader,       # Bộ dữ liệu huấn luyện
    test_loader=test_loader,         # Bộ dữ liệu kiểm tra
    N_iter=args.n_iter,              # Số vòng lặp tấn công
    writer=writer,                   # TensorBoard writer để ghi log
    file=attack_image_paths,          # Lưu ảnh vào thư mục tấn công
    csv_file=attack_csv_path, 
    csv_save_path=args.save_path,    # Đường dẫn lưu file CSV
    attack_type= 2,                  # Chế độ tấn công random
)

writer.close()  # Đóng TensorBoard writer

# best_mcc = validate_score(trained_model ,test_loader)
# print(f"\nMCC after 100 times random attack: {best_mcc}")

results = validate_score(trained_model, test_loader)
print(f"MCC after 100 times random attack: {results['MCC']}")
print(f"Accuracy after 100 times random attack: {results['Accuracy']}")
print(f"TPR after 100 times random attack: {results['TPR']}")
print(f"F1-score after 100 times random attack: {results['F1 Score']}")
# Out:
# **Test** MCC: 0.999. Val_Loss: 0.006
# ACC: 1.000.
# TPR: 0.988.
# F1-score: 0.988.
# Attack sample size is 256
# **********************************
# attacked module: stage_1.2.conv_a
# attacked weight index: 1125
# weight before attack: tensor(-0.0761, device='cuda:0')
# weight after attack: tensor(-3., device='cuda:0')
# Iteration: [001/025]   Attack Time 8.245 (8.245)
# Bit flips: 1
# Hamming distance: 1
# **Test** MCC: 0.999. Val_Loss: 0.006
# ACC: 1.000.
# TPR: 0.988.
# F1-score: 0.988.
# Iteration Time 8.836 (8.836)
# **********************************
# attacked module: stage_1.13.conv_a
# attacked weight index: 2994
# weight before attack: tensor(0.0510, device='cuda:0')
# weight after attack: tensor(8., device='cuda:0')
# Iteration: [002/025]   Attack Time 8.239 (8.242)
# Bit flips: 2
# Hamming distance: 2
# **Test** MCC: 0.999. Val_Loss: 0.006
# ACC: 1.000.
# TPR: 0.988.
# F1-score: 0.988.
# Iteration Time 9.092 (8.964)
# **********************************
# attacked module: stage_2.9.conv_b
# attacked weight index: 7670
# weight before attack: tensor(-0.0595, device='cuda:0')
# weight after attack: tensor(127., device='cuda:0')
# Iteration: [003/025]   Attack Time 8.251 (8.245)
# Bit flips: 3
# Hamming distance: 3
# **Test** MCC: 0.999. Val_Loss: 0.006
# ACC: 1.000.
# TPR: 0.988.
# F1-score: 0.988.
# Iteration Time 9.182 (9.037)
# **********************************
# attacked module: stage_3.7.conv_a
# attacked weight index: 43461
# weight before attack: tensor(-0.1220, device='cuda:0')
# weight after attack: tensor(-65., device='cuda:0')
# Iteration: [004/025]   Attack Time 8.262 (8.249)
# Bit flips: 4
# Hamming distance: 4
# **Test** MCC: 0.999. Val_Loss: 0.006
# ACC: 1.000.
# TPR: 0.988.
# F1-score: 0.988.
# Iteration Time 9.790 (9.225)
# **********************************
# attacked module: stage_2.10.conv_b
# attacked weight index: 1529
# weight before attack: tensor(0.0235, device='cuda:0')
# weight after attack: tensor(64., device='cuda:0')
# Iteration: [005/025]   Attack Time 8.540 (8.307)
# Bit flips: 5
# Hamming distance: 5
# **Test** MCC: 0.999. Val_Loss: 0.006
# ACC: 1.000.
# TPR: 0.988.
# F1-score: 0.988.
# Iteration Time 9.038 (9.188)
# **********************************
# attacked module: classifier
# attacked weight index: 491
# weight before attack: tensor(0.0518, device='cuda:0')
# weight after attack: tensor(8., device='cuda:0')
# Iteration: [006/025]   Attack Time 8.122 (8.277)
# Bit flips: 6
# Hamming distance: 5
# **Test** MCC: 0.999. Val_Loss: 0.006
# ACC: 1.000.
# TPR: 0.987.
# F1-score: 0.986.
# Iteration Time 9.166 (9.184)
# **********************************
# attacked module: stage_3.0.conv_a
# attacked weight index: 4287
# weight before attack: tensor(-0.0384, device='cuda:0')
# weight after attack: tensor(-33., device='cuda:0')
# Iteration: [007/025]   Attack Time 8.239 (8.271)
# Bit flips: 7
# Hamming distance: 6
# **Test** MCC: 0.999. Val_Loss: 0.006
# ACC: 1.000.
# TPR: 0.987.
# F1-score: 0.986.
# Iteration Time 9.041 (9.164)
# **********************************
# attacked module: stage_3.10.conv_b
# attacked weight index: 39525
# weight before attack: tensor(-0.1242, device='cuda:0')
# weight after attack: tensor(-33., device='cuda:0')
# Iteration: [008/025]   Attack Time 8.142 (8.255)
# Bit flips: 8
# Hamming distance: 7
# **Test** MCC: 0.999. Val_Loss: 0.006
# ACC: 1.000.
# TPR: 0.987.
# F1-score: 0.986.
# Iteration Time 9.119 (9.158)
# **********************************
# attacked module: classifier
# attacked weight index: 196
# weight before attack: tensor(0.0422, device='cuda:0')
# weight after attack: tensor(4096., device='cuda:0')
# Iteration: [009/025]   Attack Time 8.206 (8.250)
# Bit flips: 9
# Hamming distance: 7
# **Test** MCC: 0.229. Val_Loss: 2713.120
# ACC: 0.017.
# TPR: 0.252.
# F1-score: 0.269.
# Iteration Time 9.148 (9.157)
# **********************************
# attacked module: stage_1.14.conv_b
# attacked weight index: 289
# weight before attack: tensor(0.1243, device='cuda:0')
# weight after attack: tensor(-128., device='cuda:0')
# Iteration: [010/025]   Attack Time 8.370 (8.262)
# Bit flips: 10
# Hamming distance: 8
# **Test** MCC: 0.229. Val_Loss: 2436.464
# ACC: 0.017.
# TPR: 0.252.
# F1-score: 0.269.
# Iteration Time 9.188 (9.160)
# **********************************
# attacked module: stage_2.2.conv_b
# attacked weight index: 10700
# weight before attack: tensor(0.0127, device='cuda:0')
# weight after attack: tensor(-128., device='cuda:0')
# Iteration: [011/025]   Attack Time 8.426 (8.277)
# Bit flips: 11
# Hamming distance: 9
# **Test** MCC: 0.229. Val_Loss: 2436.464
# ACC: 0.017.
# TPR: 0.252.
# F1-score: 0.269.
# Iteration Time 9.148 (9.159)
# **********************************
# attacked module: stage_3.7.conv_a
# attacked weight index: 6358
# weight before attack: tensor(-0.0079, device='cuda:0')
# weight after attack: tensor(127., device='cuda:0')
# Iteration: [012/025]   Attack Time 8.231 (8.273)
# Bit flips: 12
# Hamming distance: 10
# **Test** MCC: 0.225. Val_Loss: 2498.760
# ACC: 0.016.
# TPR: 0.250.
# F1-score: 0.266.
# Iteration Time 8.996 (9.145)
# **********************************
# attacked module: stage_3.11.conv_a
# attacked weight index: 19787
# weight before attack: tensor(0.0548, device='cuda:0')
# weight after attack: tensor(64., device='cuda:0')
# Iteration: [013/025]   Attack Time 8.423 (8.284)
# Bit flips: 13
# Hamming distance: 11
# **Test** MCC: 0.225. Val_Loss: 2498.760
# ACC: 0.016.
# TPR: 0.250.
# F1-score: 0.266.
# Iteration Time 9.264 (9.154)
# **********************************
# attacked module: stage_2.10.conv_b
# attacked weight index: 7998
# weight before attack: tensor(-0.0671, device='cuda:0')
# weight after attack: tensor(-9., device='cuda:0')
# Iteration: [014/025]   Attack Time 8.230 (8.280)
# Bit flips: 14
# Hamming distance: 12
# **Test** MCC: 0.225. Val_Loss: 2498.760
# ACC: 0.016.
# TPR: 0.250.
# F1-score: 0.266.
# Iteration Time 9.130 (9.153)
# **********************************
# attacked module: stage_2.7.conv_a
# attacked weight index: 5544
# weight before attack: tensor(-0.1518, device='cuda:0')
# weight after attack: tensor(-5., device='cuda:0')
# Iteration: [015/025]   Attack Time 8.289 (8.281)
# Bit flips: 15
# Hamming distance: 13
# **Test** MCC: 0.225. Val_Loss: 2498.760
# ACC: 0.016.
# TPR: 0.250.
# F1-score: 0.266.
# Iteration Time 9.135 (9.152)
# **********************************
# attacked module: stage_1.2.conv_b
# attacked weight index: 1661
# weight before attack: tensor(-0.1100, device='cuda:0')
# weight after attack: tensor(-9., device='cuda:0')
# Iteration: [016/025]   Attack Time 8.367 (8.286)
# Bit flips: 16
# Hamming distance: 14
# **Test** MCC: 0.225. Val_Loss: 2498.760
# ACC: 0.016.
# TPR: 0.250.
# F1-score: 0.266.
# Iteration Time 9.392 (9.167)
# **********************************
# attacked module: stage_1.4.conv_b
# attacked weight index: 491
# weight before attack: tensor(0.3021, device='cuda:0')
# weight after attack: tensor(32., device='cuda:0')
# Iteration: [017/025]   Attack Time 8.243 (8.284)
# Bit flips: 17
# Hamming distance: 15
# **Test** MCC: 0.225. Val_Loss: 2498.760
# ACC: 0.016.
# TPR: 0.250.
# F1-score: 0.266.
# Iteration Time 9.175 (9.167)
# **********************************
# attacked module: stage_3.14.conv_a
# attacked weight index: 21883
# weight before attack: tensor(-0.0367, device='cuda:0')
# weight after attack: tensor(-65., device='cuda:0')
# Iteration: [018/025]   Attack Time 8.518 (8.297)
# Bit flips: 18
# Hamming distance: 16
# **Test** MCC: 0.225. Val_Loss: 2510.353
# ACC: 0.016.
# TPR: 0.250.
# F1-score: 0.266.
# Iteration Time 9.076 (9.162)
# **********************************
# attacked module: stage_3.7.conv_a
# attacked weight index: 2815
# weight before attack: tensor(-0.0350, device='cuda:0')
# weight after attack: tensor(-9., device='cuda:0')
# Iteration: [019/025]   Attack Time 8.206 (8.292)
# Bit flips: 19
# Hamming distance: 17
# **Test** MCC: 0.225. Val_Loss: 2509.379
# ACC: 0.016.
# TPR: 0.250.
# F1-score: 0.266.
# Iteration Time 9.030 (9.155)
# **********************************
# attacked module: stage_3.3.conv_a
# attacked weight index: 35533
# weight before attack: tensor(0.0736, device='cuda:0')
# weight after attack: tensor(16., device='cuda:0')
# Iteration: [020/025]   Attack Time 8.165 (8.286)
# Bit flips: 20
# Hamming distance: 18
# **Test** MCC: 0.225. Val_Loss: 2505.758
# ACC: 0.016.
# TPR: 0.250.
# F1-score: 0.266.
# Iteration Time 8.904 (9.143)
# **********************************
# attacked module: stage_3.6.conv_a
# attacked weight index: 5868
# weight before attack: tensor(-0.0345, device='cuda:0')
# weight after attack: tensor(127., device='cuda:0')
# Iteration: [021/025]   Attack Time 8.368 (8.290)
# Bit flips: 21
# Hamming distance: 19
# **Test** MCC: 0.225. Val_Loss: 2505.758
# ACC: 0.016.
# TPR: 0.250.
# F1-score: 0.266.
# Iteration Time 9.002 (9.136)
# **********************************
# attacked module: stage_1.6.conv_a
# attacked weight index: 2705
# weight before attack: tensor(-0.1450, device='cuda:0')
# weight after attack: tensor(-2., device='cuda:0')
# Iteration: [022/025]   Attack Time 8.142 (8.283)
# Bit flips: 22
# Hamming distance: 20
# **Test** MCC: 0.225. Val_Loss: 2505.758
# ACC: 0.016.
# TPR: 0.250.
# F1-score: 0.266.
# Iteration Time 9.055 (9.132)
# **********************************
# attacked module: stage_3.10.conv_b
# attacked weight index: 27871
# weight before attack: tensor(0.0093, device='cuda:0')
# weight after attack: tensor(64., device='cuda:0')
# Iteration: [023/025]   Attack Time 8.251 (8.281)
# Bit flips: 23
# Hamming distance: 21
# **Test** MCC: 0.225. Val_Loss: 2716.316
# ACC: 0.016.
# TPR: 0.250.
# F1-score: 0.266.
# Iteration Time 9.053 (9.129)
# **********************************
# attacked module: stage_2.1.conv_a
# attacked weight index: 2861
# weight before attack: tensor(0.2132, device='cuda:0')
# weight after attack: tensor(-128., device='cuda:0')
# Iteration: [024/025]   Attack Time 8.461 (8.289)
# Bit flips: 24
# Hamming distance: 22
# **Test** MCC: 0.225. Val_Loss: 2716.316
# ACC: 0.016.
# TPR: 0.250.
# F1-score: 0.266.
# Iteration Time 8.911 (9.120)
# **********************************
# attacked module: stage_2.3.conv_a
# attacked weight index: 7445
# weight before attack: tensor(-0.0054, device='cuda:0')
# weight after attack: tensor(-3., device='cuda:0')
# Iteration: [025/025]   Attack Time 8.358 (8.292)
# Bit flips: 25
# Hamming distance: 23
# **Test** MCC: 0.225. Val_Loss: 2716.316
# ACC: 0.016.
# TPR: 0.250.
# F1-score: 0.266.
# Iteration Time 8.954 (9.113)
# Plot saved as CustomModel/RandomFlip_attack/MCC_RandomFlip_attack.png
# Plot saved as CustomModel/RandomFlip_attack/ACC_RandomFlip_attack.png
# Plot saved as CustomModel/RandomFlip_attack/TPR_RandomFlip_attack.png
# Plot saved as CustomModel/RandomFlip_attack/F1_RandomFlip_attack.png
# [Combined Plot] Saved as CustomModel/RandomFlip_attack/combined_metrics_RandomFlip_attack.png
# MCC after 100 times random attack: 0.22528821398084503
# Accuracy after 100 times random attack: 0.016442857142857144
# TPR after 100 times random attack: 0.25019831738028947
# F1-score after 100 times random attack: 0.26616577608277203

# %%
# Bước 1: Tải mô hình đã huấn luyện
model_path = os.path.join("CustomModel", "best_model.pth")
trained_model = CustomModel()

# Tải trọng số từ file best_model.pth
trained_model.load_state_dict(torch.load(model_path, map_location=torch.device('cuda' if torch.cuda.is_available() else 'cpu')))
trained_model = trained_model.to(device)

# Bước 2: Tạo bản sao của mô hình để làm tham chiếu
model_clean = copy.deepcopy(trained_model)

# Bước 3: Khởi tạo đối tượng tấn công BFA
attacker = BFA(criterion=criterion, model=trained_model, k_top=10)

# Định nghĩa đường dẫn để lưu kết quả tấn công
attack_dir = os.path.join("CustomModel", "PBS_to_RandomFlip_attack")

os.makedirs(attack_dir, exist_ok=True)
attack_image_paths = [os.path.join(attack_dir, f"{metric}_PBS_to_RandomFlip_attack.png") 
                      for metric in ["MCC", "ACC", "TPR", "F1"]]
# attack_image_path = os.path.join(attack_dir, "PBS_to_RandomFlip_attack.png")
attack_csv_path = os.path.join(attack_dir, "PBS_to_RandomFlip_attack.csv")

# Bước 4: Thực hiện tấn công
perform_attack(
    attacker=attacker,               # Đối tượng tấn công
    model=trained_model,             # Mô hình bị tấn công
    model_clean=model_clean,         # Mô hình gốc làm tham chiếu
    train_loader=train_loader,       # Bộ dữ liệu huấn luyện
    test_loader=test_loader,         # Bộ dữ liệu kiểm tra
    N_iter=args.n_iter,              # Số vòng lặp tấn công
    writer=writer,                   # TensorBoard writer để ghi log
    file=attack_image_paths,          # Lưu ảnh vào thư mục tấn công
    csv_file=attack_csv_path,
    csv_save_path=args.save_path,    # Đường dẫn lưu file CSV
    attack_type= 3,                  # Chế độ tấn công PBS -> random
)

writer.close()  # Đóng TensorBoard writer
# best_mcc = validate_score( trained_model,test_loader)
# print(f"\nMCC after 100 times PBS to Random: {best_mcc}")

results = validate_score(trained_model, test_loader)
print(f"MCC after 100 times PBS to Random: {results['MCC']}")
print(f"Accuracy after 100 times PBS to Random: {results['Accuracy']}")
print(f"TPR after 100 times PBS to Random: {results['TPR']}")
print(f"F1-score after 100 times PBS to Random: {results['F1 Score']}")
# Out:
# **Test** MCC: 0.999. Val_Loss: 0.006
# ACC: 1.000.
# TPR: 0.988.
# F1-score: 0.988.
# Attack sample size is 256
# **********************************
# attacked module: fc1
# attacked module: stage_1.5.conv_a
# attacked weight index: 1768
# weight before attack: tensor(0.2741, device='cuda:0')
# weight after attack: tensor(4., device='cuda:0')
# Iteration: [001/025]   Attack Time 18.077 (18.077)
# Loss before attack: 0.0000
# Loss after attack: 46.6530
# Bit flips: 2
# Hamming distance: 2
# **Test** MCC: -0.407. Val_Loss: 45.265
# ACC: 0.059.
# TPR: 0.325.
# F1-score: 0.163.
# Iteration Time 9.027 (9.027)
# **********************************
# attacked module: stage_1.0.conv_a
# attacked module: stage_1.10.conv_a
# attacked weight index: 256
# weight before attack: tensor(0.1538, device='cuda:0')
# weight after attack: tensor(-128., device='cuda:0')
# Iteration: [002/025]   Attack Time 18.318 (18.198)
# Loss before attack: 45.6027
# Loss after attack: 3291.9919
# Bit flips: 4
# Hamming distance: 4
# **Test** MCC: -0.445. Val_Loss: 3226.243
# ACC: 0.054.
# TPR: 0.319.
# F1-score: 0.163.
# Iteration Time 9.074 (9.051)
# **********************************
# attacked module: stage_1.0.conv_b
# attacked module: stage_3.5.conv_a
# attacked weight index: 7496
# weight before attack: tensor(-0.0361, device='cuda:0')
# weight after attack: tensor(-9., device='cuda:0')
# Iteration: [003/025]   Attack Time 18.138 (18.178)
# Loss before attack: 3291.9919
# Loss after attack: 247680.5312
# Bit flips: 6
# Hamming distance: 6
# **Test** MCC: -0.118. Val_Loss: 242674.029
# ACC: 0.069.
# TPR: 0.362.
# F1-score: 0.082.
# Iteration Time 9.004 (9.035)
# **********************************
# attacked module: stage_1.1.conv_b
# attacked module: stage_3.9.conv_b
# attacked weight index: 36265
# weight before attack: tensor(-0.0590, device='cuda:0')
# weight after attack: tensor(-17., device='cuda:0')
# Iteration: [004/025]   Attack Time 18.092 (18.156)
# Loss before attack: 247680.5312
# Loss after attack: 3956208.5000
# Bit flips: 8
# Hamming distance: 8
# **Test** MCC: -0.224. Val_Loss: 3876079.996
# ACC: 0.063.
# TPR: 0.326.
# F1-score: 0.051.
# Iteration Time 9.056 (9.040)
# **********************************
# attacked module: stage_1.1.conv_a
# attacked module: stage_3.15.conv_b
# attacked weight index: 21891
# weight before attack: tensor(-0.0197, device='cuda:0')
# weight after attack: tensor(-33., device='cuda:0')
# Iteration: [005/025]   Attack Time 17.872 (18.099)
# Loss before attack: 3956208.5000
# Loss after attack: 1414190592.0000
# Bit flips: 10
# Hamming distance: 10
# **Test** MCC: -0.175. Val_Loss: 1385547428.718
# ACC: 0.067.
# TPR: 0.349.
# F1-score: 0.081.
# Iteration Time 8.996 (9.032)
# **********************************
# attacked module: stage_1.4.conv_a
# attacked module: stage_1.1.conv_b
# attacked weight index: 2097
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-33., device='cuda:0')
# Iteration: [006/025]   Attack Time 18.174 (18.112)
# Loss before attack: 1414190592.0000
# Loss after attack: 27263299584.0000
# Bit flips: 12
# Hamming distance: 12
# **Test** MCC: -0.123. Val_Loss: 26718234873.037
# ACC: 0.069.
# TPR: 0.362.
# F1-score: 0.083.
# Iteration Time 9.352 (9.085)
# **********************************
# attacked module: stage_1.7.conv_b
# attacked module: stage_3.2.conv_b
# attacked weight index: 46986
# weight before attack: tensor(0.0885, device='cuda:0')
# weight after attack: tensor(1., device='cuda:0')
# Iteration: [007/025]   Attack Time 18.802 (18.210)
# Loss before attack: 27263299584.0000
# Loss after attack: 457381380096.0000
# Bit flips: 14
# Hamming distance: 14
# **Test** MCC: -0.120. Val_Loss: 448256358399.532
# ACC: 0.068.
# TPR: 0.339.
# F1-score: 0.051.
# Iteration Time 9.167 (9.097)
# **********************************
# attacked module: stage_1.7.conv_a
# attacked module: stage_1.12.conv_a
# attacked weight index: 1564
# weight before attack: tensor(-0.2652, device='cuda:0')
# weight after attack: tensor(-65., device='cuda:0')
# Iteration: [008/025]   Attack Time 18.068 (18.193)
# Loss before attack: 457381380096.0000
# Loss after attack: 55557524291584.0000
# Bit flips: 16
# Hamming distance: 16
# **Test** MCC: 0.004. Val_Loss: 54447434995342.656
# ACC: 0.068.
# TPR: 0.355.
# F1-score: 0.046.
# Iteration Time 9.115 (9.099)
# **********************************
# attacked module: stage_1.4.conv_b
# attacked module: stage_2.11.conv_a
# attacked weight index: 5928
# weight before attack: tensor(0.0105, device='cuda:0')
# weight after attack: tensor(4., device='cuda:0')
# Iteration: [009/025]   Attack Time 18.125 (18.185)
# Loss before attack: 55557524291584.0000
# Loss after attack: 23045282681847808.0000
# Bit flips: 18
# Hamming distance: 18
# **Test** MCC: 0.003. Val_Loss: 22585242169608952.000
# ACC: 0.068.
# TPR: 0.354.
# F1-score: 0.045.
# Iteration Time 9.064 (9.095)
# **********************************
# attacked module: stage_3.1.conv_a
# attacked module: stage_1.1.conv_b
# attacked weight index: 914
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(8., device='cuda:0')
# Iteration: [010/025]   Attack Time 21.946 (18.561)
# Loss before attack: 23045282681847808.0000
# Loss after attack: 405662925282344960.0000
# Bit flips: 20
# Hamming distance: 20
# **Test** MCC: 0.003. Val_Loss: 396117041863856704.000
# ACC: 0.002.
# TPR: 0.017.
# F1-score: 0.001.
# Iteration Time 9.168 (9.102)
# **********************************
# attacked module: stage_3.1.conv_b
# attacked module: stage_1.5.conv_a
# attacked weight index: 809
# weight before attack: tensor(-0.0812, device='cuda:0')
# weight after attack: tensor(-5., device='cuda:0')
# Iteration: [011/025]   Attack Time 21.689 (18.846)
# Loss before attack: 405662925282344960.0000
# Loss after attack: 65536412563821035520.0000
# Bit flips: 22
# Hamming distance: 22
# **Test** MCC: 0.002. Val_Loss: 63864672897883004928.000
# ACC: 0.008.
# TPR: 0.265.
# F1-score: 0.005.
# Iteration Time 9.286 (9.119)
# **********************************
# attacked module: stage_3.4.conv_a
# attacked module: stage_3.10.conv_b
# attacked weight index: 38253
# weight before attack: tensor(-0.0714, device='cuda:0')
# weight after attack: tensor(-5., device='cuda:0')
# Iteration: [012/025]   Attack Time 22.154 (19.121)
# Loss before attack: 65536412563821035520.0000
# Loss after attack: 2088299303225840893952.0000
# Bit flips: 24
# Hamming distance: 24
# **Test** MCC: 0.002. Val_Loss: 2023393715524499144704.000
# ACC: 0.008.
# TPR: 0.265.
# F1-score: 0.005.
# Iteration Time 9.006 (9.110)
# **********************************
# attacked module: stage_3.12.conv_b
# attacked module: stage_1.10.conv_b
# attacked weight index: 2117
# weight before attack: tensor(-0.0419, device='cuda:0')
# weight after attack: tensor(-9., device='cuda:0')
# Iteration: [013/025]   Attack Time 21.883 (19.334)
# Loss before attack: 2088299303225840893952.0000
# Loss after attack: 22550367759174205440000.0000
# Bit flips: 26
# Hamming distance: 26
# **Test** MCC: 0.002. Val_Loss: 21825980427577252118528.000
# ACC: 0.001.
# TPR: 0.017.
# F1-score: 0.001.
# Iteration Time 9.118 (9.110)
# **********************************
# attacked module: stage_3.12.conv_a
# attacked module: stage_2.7.conv_a
# attacked weight index: 3584
# weight before attack: tensor(0.0294, device='cuda:0')
# weight after attack: tensor(2., device='cuda:0')
# Iteration: [014/025]   Attack Time 22.006 (19.525)
# Loss before attack: 22550367759174205440000.0000
# Loss after attack: 3867012000989192380219392.0000
# Bit flips: 28
# Hamming distance: 28
# **Test** MCC: 0.002. Val_Loss: 3743260469634784244531200.000
# ACC: 0.001.
# TPR: 0.017.
# F1-score: 0.001.
# Iteration Time 9.061 (9.107)
# **********************************
# attacked module: stage_3.4.conv_b
# attacked module: stage_1.4.conv_b
# attacked weight index: 2654
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(1., device='cuda:0')
# Iteration: [015/025]   Attack Time 21.903 (19.683)
# Loss before attack: 3867012000989192380219392.0000
# Loss after attack: 1072423971752874708849131520.0000
# Bit flips: 30
# Hamming distance: 30
# **Test** MCC: 0.002. Val_Loss: 1038073906730491895900798976.000
# ACC: 0.001.
# TPR: 0.017.
# F1-score: 0.001.
# Iteration Time 8.952 (9.096)
# **********************************
# attacked module: stage_1.2.conv_b
# attacked module: stage_2.10.conv_b
# attacked weight index: 7132
# weight before attack: tensor(-0.0478, device='cuda:0')
# weight after attack: tensor(127., device='cuda:0')
# Iteration: [016/025]   Attack Time 17.983 (19.577)
# Loss before attack: 1072423971752874708849131520.0000
# Loss after attack: 10307837526630134048276611072.0000
# Bit flips: 32
# Hamming distance: 32
# **Test** MCC: 0.000. Val_Loss: 9977337829312377546778607616.000
# ACC: 0.000.
# TPR: 0.016.
# F1-score: 0.000.
# Iteration Time 9.015 (9.091)
# **********************************
# attacked module: stage_1.2.conv_a
# attacked module: stage_3.9.conv_a
# attacked weight index: 31731
# weight before attack: tensor(-0.0925, device='cuda:0')
# weight after attack: tensor(-3., device='cuda:0')
# Iteration: [017/025]   Attack Time 17.585 (19.460)
# Loss before attack: 10307837526630134048276611072.0000
# Loss after attack: 4105986889026934322910539546624.0000
# Bit flips: 34
# Hamming distance: 34
# **Test** MCC: 0.002. Val_Loss: 3974787507404355737763931226112.000
# ACC: 0.001.
# TPR: 0.017.
# F1-score: 0.001.
# Iteration Time 9.164 (9.096)
# **********************************
# attacked module: stage_1.3.conv_b
# attacked module: stage_1.13.conv_a
# attacked weight index: 3024
# weight before attack: tensor(0.1149, device='cuda:0')
# weight after attack: tensor(1., device='cuda:0')
# Iteration: [018/025]   Attack Time 18.049 (19.381)
# Loss before attack: 4105986889026934322910539546624.0000
# Loss after attack: 37665981923630566905775201976320.0000
# Bit flips: 36
# Hamming distance: 36
# **Test** MCC: 0.007. Val_Loss: 36456588357214523364951688478720.000
# ACC: 0.005.
# TPR: 0.018.
# F1-score: 0.003.
# Iteration Time 8.802 (9.079)
# **********************************
# attacked module: stage_1.3.conv_a
# attacked module: stage_1.6.conv_a
# attacked weight index: 2648
# weight before attack: tensor(0.0910, device='cuda:0')
# weight after attack: tensor(4., device='cuda:0')
# Iteration: [019/025]   Attack Time 18.320 (19.326)
# Loss before attack: 37665981923630566905775201976320.0000
# Loss after attack: 8384384670954066365611083298766848.0000
# Bit flips: 38
# Hamming distance: 38
# **Test** MCC: 0.001. Val_Loss: 8116389098321282328730905402671104.000
# ACC: 0.001.
# TPR: 0.017.
# F1-score: 0.000.
# Iteration Time 9.180 (9.085)
# **********************************
# attacked module: stage_3.15.conv_a
# attacked module: stage_3.9.conv_b
# attacked weight index: 11319
# weight before attack: tensor(0.0728, device='cuda:0')
# weight after attack: tensor(-128., device='cuda:0')
# Iteration: [020/025]   Attack Time 21.467 (19.433)
# Loss before attack: 8384384670954066365611083298766848.0000
# Loss after attack: 72999442447799161032783508820459520.0000
# Bit flips: 40
# Hamming distance: 40
# **Test** MCC: 0.001. Val_Loss: 70698430664379233908300466635145216.000
# ACC: 0.001.
# TPR: 0.017.
# F1-score: 0.000.
# Iteration Time 8.976 (9.079)
# **********************************
# attacked module: stage_1.5.conv_b
# attacked module: stage_1.12.conv_a
# attacked weight index: 1414
# weight before attack: tensor(-0.1182, device='cuda:0')
# weight after attack: tensor(-3., device='cuda:0')
# Iteration: [021/025]   Attack Time 17.994 (19.364)
# Loss before attack: 72999442447799161032783508820459520.0000
# Loss after attack: 516112136886708975433081272020238336.0000
# Bit flips: 42
# Hamming distance: 42
# **Test** MCC: 0.004. Val_Loss: 499831874656700437412437283326394368.000
# ACC: 0.003.
# TPR: 0.015.
# F1-score: 0.002.
# Iteration Time 8.794 (9.066)
# **********************************
# attacked module: stage_1.6.conv_b
# attacked module: stage_1.11.conv_a
# attacked weight index: 2874
# weight before attack: tensor(-0.1610, device='cuda:0')
# weight after attack: tensor(-3., device='cuda:0')
# Iteration: [022/025]   Attack Time 18.004 (19.302)
# Loss before attack: 516112136886708975433081272020238336.0000
# Loss after attack: inf
# Bit flips: 44
# Hamming distance: 44
# **Test** MCC: -0.004. Val_Loss: inf
# ACC: 0.004.
# TPR: 0.017.
# F1-score: 0.002.
# Iteration Time 9.178 (9.071)
# **********************************
# attacked module: fc1
# attacked module: stage_2.2.conv_a
# attacked weight index: 1947
# weight before attack: tensor(0.2837, device='cuda:0')
# weight after attack: tensor(2., device='cuda:0')
# Iteration: [023/025]   Attack Time 17.975 (19.245)
# Loss before attack: inf
# Loss after attack: nan
# Bit flips: 46
# Hamming distance: 46
# **Test** MCC: -0.001. Val_Loss: nan
# ACC: 0.003.
# TPR: 0.012.
# F1-score: 0.003.
# Iteration Time 9.230 (9.078)
# **********************************
# attacked module: stage_2.4.conv_b
# attacked weight index: 3919
# weight before attack: tensor(0.0182, device='cuda:0')
# weight after attack: tensor(1., device='cuda:0')
# Iteration: [024/025]   Attack Time 16.986 (19.150)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 47
# Hamming distance: 47
# **Test** MCC: -0.001. Val_Loss: nan
# ACC: 0.003.
# TPR: 0.012.
# F1-score: 0.003.
# Iteration Time 9.141 (9.080)
# **********************************
# attacked module: stage_1.2.conv_b
# attacked weight index: 476
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(32., device='cuda:0')
# Iteration: [025/025]   Attack Time 16.543 (19.046)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 48
# Hamming distance: 48
# **Test** MCC: -0.001. Val_Loss: nan
# ACC: 0.003.
# TPR: 0.012.
# F1-score: 0.003.
# Iteration Time 9.284 (9.088)
# Plot saved as CustomModel/PBS_to_RandomFlip_attack/MCC_PBS_to_RandomFlip_attack.png
# Plot saved as CustomModel/PBS_to_RandomFlip_attack/ACC_PBS_to_RandomFlip_attack.png
# Plot saved as CustomModel/PBS_to_RandomFlip_attack/TPR_PBS_to_RandomFlip_attack.png
# Plot saved as CustomModel/PBS_to_RandomFlip_attack/F1_PBS_to_RandomFlip_attack.png
# [Combined Plot] Saved as CustomModel/PBS_to_RandomFlip_attack/combined_metrics_PBS_to_RandomFlip_attack.png
# MCC after 100 times PBS to Random: -0.0009961019963988763
# Accuracy after 100 times PBS to Random: 0.003492857142857143
# TPR after 100 times PBS to Random: 0.012486505890375222
# F1-score after 100 times PBS to Random: 0.003159390898286819

# %%
# Bước 1: Tải mô hình đã huấn luyện
model_path = os.path.join("CustomModel", "best_model.pth")
trained_model = CustomModel()

# Tải trọng số từ file best_model.pth
trained_model.load_state_dict(torch.load(model_path, map_location=torch.device('cuda' if torch.cuda.is_available() else 'cpu')))
trained_model = trained_model.to(device)

# Bước 2: Tạo bản sao của mô hình để làm tham chiếu
model_clean = copy.deepcopy(trained_model)

# Bước 3: Khởi tạo đối tượng tấn công BFA
attacker = BFA(criterion=criterion, model=trained_model, k_top=10)

# Định nghĩa đường dẫn để lưu kết quả tấn công
attack_dir = os.path.join("CustomModel", "RandomFlip_to_PBS_attack")

os.makedirs(attack_dir, exist_ok=True)
attack_image_paths = [os.path.join(attack_dir, f"{metric}_RandomFlip_to_PBS_attack.png") 
                      for metric in ["MCC", "ACC", "TPR", "F1"]]
# attack_image_path = os.path.join(attack_dir, "RandomFlip_to_PBS_attack.png")
attack_csv_path = os.path.join(attack_dir, "RandomFlip_to_PBS_attack.csv")

# Bước 4: Thực hiện tấn công
perform_attack(
    attacker=attacker,               # Đối tượng tấn công
    model=trained_model,             # Mô hình bị tấn công
    model_clean=model_clean,         # Mô hình gốc làm tham chiếu
    train_loader=train_loader,       # Bộ dữ liệu huấn luyện
    test_loader=test_loader,         # Bộ dữ liệu kiểm tra
    N_iter=args.n_iter,              # Số vòng lặp tấn công
    writer=writer,                   # TensorBoard writer để ghi log
    file=attack_image_paths,          # Lưu ảnh vào thư mục tấn công
    csv_file=attack_csv_path,  
    csv_save_path=args.save_path,    # Đường dẫn lưu file CSV
    attack_type= 4,                  # Chế độ tấn công Random -> PBS
)

writer.close()  # Đóng TensorBoard writer
# best_mcc = validate_score( trained_model,test_loader)
# print(f"\nMCC after 100 times random to PBS: {best_mcc}")

results = validate_score(trained_model, test_loader)
print(f"MCC after 100 times random to PBS: {results['MCC']}")
print(f"Accuracy after 100 times random to PBS: {results['Accuracy']}")
print(f"TPR after 100 times random to PBS: {results['TPR']}")
print(f"F1-score after 100 times random to PBS: {results['F1 Score']}")
# Out:
# **Test** MCC: 0.999. Val_Loss: 0.006
# ACC: 1.000.
# TPR: 0.988.
# F1-score: 0.988.
# Attack sample size is 256
# **********************************
# attacked module: stage_3.1.conv_b
# attacked weight index: 40017
# weight before attack: tensor(-0.0007, device='cuda:0')
# weight after attack: tensor(-3., device='cuda:0')
# attacked module: stage_2.12.conv_a
# Iteration: [001/025]   Attack Time 19.573 (19.573)
# Loss before attack: 0.0000
# Loss after attack: 34.7348
# Bit flips: 2
# Hamming distance: 2
# **Test** MCC: 0.479. Val_Loss: 35.042
# ACC: 0.073.
# TPR: 0.604.
# F1-score: 0.344.
# Iteration Time 9.387 (9.387)
# **********************************
# attacked module: stage_2.4.conv_b
# attacked weight index: 4155
# weight before attack: tensor(0.0504, device='cuda:0')
# weight after attack: tensor(64., device='cuda:0')
# attacked module: stage_2.12.conv_b
# Iteration: [002/025]   Attack Time 18.944 (19.259)
# Loss before attack: 34.7348
# Loss after attack: 4708.1084
# Bit flips: 4
# Hamming distance: 4
# **Test** MCC: 0.479. Val_Loss: 4749.133
# ACC: 0.073.
# TPR: 0.604.
# F1-score: 0.344.
# Iteration Time 8.943 (9.165)
# **********************************
# attacked module: stage_1.2.conv_a
# attacked weight index: 1830
# weight before attack: tensor(-0.0696, device='cuda:0')
# weight after attack: tensor(127., device='cuda:0')
# attacked module: stage_3.4.conv_a
# Iteration: [003/025]   Attack Time 22.188 (20.235)
# Loss before attack: 4708.1084
# Loss after attack: 104692.3984
# Bit flips: 6
# Hamming distance: 6
# **Test** MCC: 0.479. Val_Loss: 105605.031
# ACC: 0.073.
# TPR: 0.604.
# F1-score: 0.344.
# Iteration Time 9.144 (9.158)
# **********************************
# attacked module: stage_3.3.conv_a
# attacked weight index: 2707
# weight before attack: tensor(-0.0006, device='cuda:0')
# weight after attack: tensor(-65., device='cuda:0')
# attacked module: stage_3.12.conv_b
# Iteration: [004/025]   Attack Time 21.866 (20.643)
# Loss before attack: 104692.3984
# Loss after attack: 1147033.2500
# Bit flips: 8
# Hamming distance: 8
# **Test** MCC: 0.334. Val_Loss: 1156878.761
# ACC: 0.047.
# TPR: 0.160.
# F1-score: 0.172.
# Iteration Time 10.120 (9.399)
# **********************************
# attacked module: stage_1.0.conv_a
# attacked weight index: 954
# weight before attack: tensor(-0.0884, device='cuda:0')
# weight after attack: tensor(-17., device='cuda:0')
# attacked module: stage_3.12.conv_a
# Iteration: [005/025]   Attack Time 22.570 (21.028)
# Loss before attack: 1147033.2500
# Loss after attack: 190704496.0000
# Bit flips: 10
# Hamming distance: 10
# **Test** MCC: 0.448. Val_Loss: 192325579.037
# ACC: 0.060.
# TPR: 0.255.
# F1-score: 0.252.
# Iteration Time 9.172 (9.353)
# **********************************
# attacked module: stage_3.5.conv_b
# attacked weight index: 18075
# weight before attack: tensor(-0.0147, device='cuda:0')
# weight after attack: tensor(-2., device='cuda:0')
# attacked module: stage_3.4.conv_b
# Iteration: [006/025]   Attack Time 22.062 (21.201)
# Loss before attack: 190704496.0000
# Loss after attack: 52776820736.0000
# Bit flips: 12
# Hamming distance: 12
# **Test** MCC: 0.313. Val_Loss: 53227670838.594
# ACC: 0.031.
# TPR: 0.141.
# F1-score: 0.167.
# Iteration Time 9.438 (9.367)
# **********************************
# attacked module: stage_1.0.conv_b
# attacked weight index: 2244
# weight before attack: tensor(-0.2507, device='cuda:0')
# weight after attack: tensor(-3., device='cuda:0')
# attacked module: stage_2.13.conv_a
# Iteration: [007/025]   Attack Time 18.863 (20.867)
# Loss before attack: 52776820736.0000
# Loss after attack: 552814706688.0000
# Bit flips: 14
# Hamming distance: 14
# **Test** MCC: 0.050. Val_Loss: 557535192221.521
# ACC: 0.002.
# TPR: 0.029.
# F1-score: 0.019.
# Iteration Time 9.062 (9.324)
# **********************************
# attacked module: stage_1.3.conv_a
# attacked weight index: 1123
# weight before attack: tensor(0.0258, device='cuda:0')
# weight after attack: tensor(64., device='cuda:0')
# attacked module: stage_2.13.conv_b
# Iteration: [008/025]   Attack Time 18.814 (20.610)
# Loss before attack: 552837578752.0000
# Loss after attack: 100874529538048.0000
# Bit flips: 16
# Hamming distance: 16
# **Test** MCC: 0.002. Val_Loss: 101618261429531.438
# ACC: 0.000.
# TPR: 0.021.
# F1-score: 0.005.
# Iteration Time 9.493 (9.345)
# **********************************
# attacked module: stage_1.13.conv_a
# attacked weight index: 1019
# weight before attack: tensor(0.0656, device='cuda:0')
# weight after attack: tensor(64., device='cuda:0')
# attacked module: stage_1.9.conv_b
# Iteration: [009/025]   Attack Time 17.975 (20.317)
# Loss before attack: 100874529538048.0000
# Loss after attack: 1154945965359104.0000
# Bit flips: 18
# Hamming distance: 18
# **Test** MCC: 0.002. Val_Loss: 1022660477539949.000
# ACC: 0.000.
# TPR: 0.021.
# F1-score: 0.005.
# Iteration Time 9.243 (9.334)
# **********************************
# attacked module: stage_1.10.conv_b
# attacked weight index: 1940
# weight before attack: tensor(0.0079, device='cuda:0')
# weight after attack: tensor(8., device='cuda:0')
# attacked module: stage_1.9.conv_a
# Iteration: [010/025]   Attack Time 17.907 (20.076)
# Loss before attack: 1154945965359104.0000
# Loss after attack: 410003281792729088.0000
# Bit flips: 20
# Hamming distance: 20
# **Test** MCC: 0.000. Val_Loss: 320587239658045120.000
# ACC: 0.000.
# TPR: 0.016.
# F1-score: 0.000.
# Iteration Time 9.168 (9.317)
# **********************************
# attacked module: stage_1.4.conv_b
# attacked weight index: 2219
# weight before attack: tensor(0.2074, device='cuda:0')
# weight after attack: tensor(32., device='cuda:0')
# attacked module: stage_1.3.conv_b
# Iteration: [011/025]   Attack Time 17.766 (19.866)
# Loss before attack: 410003281792729088.0000
# Loss after attack: 78447251931120271360.0000
# Bit flips: 22
# Hamming distance: 22
# **Test** MCC: 0.000. Val_Loss: 61030642292909514752.000
# ACC: 0.000.
# TPR: 0.016.
# F1-score: 0.000.
# Iteration Time 9.175 (9.304)
# **********************************
# attacked module: stage_3.8.conv_b
# attacked weight index: 8671
# weight before attack: tensor(0.0024, device='cuda:0')
# weight after attack: tensor(8., device='cuda:0')
# attacked module: fc1
# Iteration: [012/025]   Attack Time 18.086 (19.718)
# Loss before attack: 78431357391029141504.0000
# Loss after attack: 4479145362868850917376.0000
# Bit flips: 24
# Hamming distance: 24
# **Test** MCC: 0.000. Val_Loss: 2266064075609741983744.000
# ACC: 0.000.
# TPR: 0.016.
# F1-score: 0.000.
# Iteration Time 9.228 (9.298)
# **********************************
# attacked module: stage_1.0.conv_b
# attacked weight index: 2378
# weight before attack: tensor(0.0469, device='cuda:0')
# weight after attack: tensor(64., device='cuda:0')
# attacked module: stage_1.0.conv_a
# Iteration: [013/025]   Attack Time 18.137 (19.596)
# Loss before attack: 4479145362868850917376.0000
# Loss after attack: 289486394058988356370432.0000
# Bit flips: 26
# Hamming distance: 26
# **Test** MCC: 0.000. Val_Loss: 146088496884710192971776.000
# ACC: 0.000.
# TPR: 0.016.
# F1-score: 0.000.
# Iteration Time 9.313 (9.299)
# **********************************
# attacked module: stage_2.6.conv_b
# attacked weight index: 9576
# weight before attack: tensor(0.0285, device='cuda:0')
# weight after attack: tensor(16., device='cuda:0')
# attacked module: stage_1.0.conv_b
# Iteration: [014/025]   Attack Time 17.731 (19.463)
# Loss before attack: 289486394058988356370432.0000
# Loss after attack: 50374507067066596374609920.0000
# Bit flips: 28
# Hamming distance: 28
# **Test** MCC: 0.000. Val_Loss: 25413386187907901813686272.000
# ACC: 0.000.
# TPR: 0.016.
# F1-score: 0.000.
# Iteration Time 9.278 (9.297)
# **********************************
# attacked module: stage_2.1.conv_a
# attacked weight index: 4684
# weight before attack: tensor(-0.0425, device='cuda:0')
# weight after attack: tensor(-3., device='cuda:0')
# attacked module: stage_1.7.conv_b
# Iteration: [015/025]   Attack Time 18.033 (19.368)
# Loss before attack: 50350512464712718675345408.0000
# Loss after attack: 1373733015665870230106669056.0000
# Bit flips: 30
# Hamming distance: 30
# **Test** MCC: 0.000. Val_Loss: 693249488097445517419610112.000
# ACC: 0.000.
# TPR: 0.016.
# F1-score: 0.000.
# Iteration Time 10.049 (9.348)
# **********************************
# attacked module: stage_2.5.conv_b
# attacked weight index: 6333
# weight before attack: tensor(-0.0388, device='cuda:0')
# weight after attack: tensor(127., device='cuda:0')
# attacked module: stage_1.7.conv_a
# Iteration: [016/025]   Attack Time 17.992 (19.282)
# Loss before attack: 1373733015665870230106669056.0000
# Loss after attack: 691871571111456216914574966784.0000
# Bit flips: 32
# Hamming distance: 32
# **Test** MCC: 0.000. Val_Loss: 349118470715255691859676102656.000
# ACC: 0.000.
# TPR: 0.016.
# F1-score: 0.000.
# Iteration Time 9.167 (9.336)
# **********************************
# attacked module: stage_1.0.conv_b
# attacked weight index: 254
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(2., device='cuda:0')
# attacked module: stage_1.1.conv_b
# Iteration: [017/025]   Attack Time 18.421 (19.231)
# Loss before attack: 691871571111456216914574966784.0000
# Loss after attack: 15200230529090123128983452123136.0000
# Bit flips: 34
# Hamming distance: 34
# **Test** MCC: 0.000. Val_Loss: 7668748789586818897861364678656.000
# ACC: 0.000.
# TPR: 0.016.
# F1-score: 0.000.
# Iteration Time 9.400 (9.340)
# **********************************
# attacked module: stage_2.15.conv_a
# attacked weight index: 530
# weight before attack: tensor(0.0185, device='cuda:0')
# weight after attack: tensor(32., device='cuda:0')
# attacked module: stage_1.1.conv_a
# Iteration: [018/025]   Attack Time 17.931 (19.159)
# Loss before attack: 15200230529090123128983452123136.0000
# Loss after attack: 3929081487982347923213687961157632.0000
# Bit flips: 36
# Hamming distance: 36
# **Test** MCC: 0.000. Val_Loss: 1982358989018246943280528380395520.000
# ACC: 0.000.
# TPR: 0.016.
# F1-score: 0.000.
# Iteration Time 9.119 (9.328)
# **********************************
# attacked module: stage_3.12.conv_a
# attacked weight index: 38899
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(64., device='cuda:0')
# attacked module: stage_1.4.conv_b
# Iteration: [019/025]   Attack Time 18.094 (19.103)
# Loss before attack: 3937867148441156267024647045775360.0000
# Loss after attack: 65970057426245300500866010932314112.0000
# Bit flips: 38
# Hamming distance: 38
# **Test** MCC: 0.000. Val_Loss: 33281731585994038889966362936999936.000
# ACC: 0.000.
# TPR: 0.016.
# F1-score: 0.000.
# Iteration Time 9.240 (9.323)
# **********************************
# attacked module: stage_1.5.conv_b
# attacked weight index: 2250
# weight before attack: tensor(0.0518, device='cuda:0')
# weight after attack: tensor(16., device='cuda:0')
# attacked module: stage_2.2.conv_b
# Iteration: [020/025]   Attack Time 19.025 (19.099)
# Loss before attack: 65970057426245300500866010932314112.0000
# Loss after attack: 754912632326677915673055783112671232.0000
# Bit flips: 40
# Hamming distance: 40
# **Test** MCC: 0.000. Val_Loss: nan
# ACC: 0.000.
# TPR: 0.016.
# F1-score: 0.000.
# Iteration Time 9.103 (9.312)
# **********************************
# attacked module: classifier
# attacked weight index: 220
# weight before attack: tensor(-0.0159, device='cuda:0')
# weight after attack: tensor(-1025., device='cuda:0')
# attacked module: fc1
# Iteration: [021/025]   Attack Time 18.431 (19.067)
# Loss before attack: 602852357243844543327725888779321344.0000
# Loss after attack: nan
# Bit flips: 42
# Hamming distance: 41
# **Test** MCC: 0.000. Val_Loss: nan
# ACC: 0.000.
# TPR: 0.010.
# F1-score: 0.000.
# Iteration Time 9.274 (9.310)
# **********************************
# attacked module: stage_2.4.conv_a
# attacked weight index: 9117
# weight before attack: tensor(0.0449, device='cuda:0')
# weight after attack: tensor(1., device='cuda:0')
# Iteration: [022/025]   Attack Time 16.432 (18.947)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 43
# Hamming distance: 42
# **Test** MCC: 0.000. Val_Loss: nan
# ACC: 0.000.
# TPR: 0.010.
# F1-score: 0.000.
# Iteration Time 9.299 (9.310)
# **********************************
# attacked module: stage_2.6.conv_b
# attacked weight index: 9955
# weight before attack: tensor(0.0338, device='cuda:0')
# weight after attack: tensor(1., device='cuda:0')
# Iteration: [023/025]   Attack Time 16.510 (18.841)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 44
# Hamming distance: 43
# **Test** MCC: 0.000. Val_Loss: nan
# ACC: 0.000.
# TPR: 0.010.
# F1-score: 0.000.
# Iteration Time 9.582 (9.322)
# **********************************
# attacked module: stage_1.1.conv_b
# attacked weight index: 1517
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(32., device='cuda:0')
# Iteration: [024/025]   Attack Time 16.585 (18.747)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 45
# Hamming distance: 44
# **Test** MCC: 0.000. Val_Loss: nan
# ACC: 0.000.
# TPR: 0.010.
# F1-score: 0.000.
# Iteration Time 9.447 (9.327)
# **********************************
# attacked module: stage_3.15.conv_b
# attacked weight index: 2645
# weight before attack: tensor(0.0515, device='cuda:0')
# weight after attack: tensor(8., device='cuda:0')
# Iteration: [025/025]   Attack Time 16.267 (18.648)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 46
# Hamming distance: 45
# **Test** MCC: 0.000. Val_Loss: nan
# ACC: 0.000.
# TPR: 0.010.
# F1-score: 0.000.
# Iteration Time 9.270 (9.325)
# Plot saved as CustomModel/RandomFlip_to_PBS_attack/MCC_RandomFlip_to_PBS_attack.png
# Plot saved as CustomModel/RandomFlip_to_PBS_attack/ACC_RandomFlip_to_PBS_attack.png
# Plot saved as CustomModel/RandomFlip_to_PBS_attack/TPR_RandomFlip_to_PBS_attack.png
# Plot saved as CustomModel/RandomFlip_to_PBS_attack/F1_RandomFlip_to_PBS_attack.png
# [Combined Plot] Saved as CustomModel/RandomFlip_to_PBS_attack/combined_metrics_RandomFlip_to_PBS_attack.png
# MCC after 100 times random to PBS: 0.0
# Accuracy after 100 times random to PBS: 0.00016428571428571428
# TPR after 100 times random to PBS: 0.010392380952380953
# F1-score after 100 times random to PBS: 8.558116553411097e-05

# %% [markdown]
# ## Train second model

# %%
'''
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = CustomModel2().to(device)
criterion = torch.nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters(), lr=0.001, weight_decay=0.01)

num_epochs = 20
patience = 10  # Số epoch để chờ trước khi dừng
counter = 0

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5)

best_val_loss = float('inf')
best_mcc = -1  # Khởi tạo MCC tốt nhất

for epoch in range(num_epochs):
    train_mcc, train_loss = train(train_loader, model, criterion, optimizer, epoch)

    val_mcc, val_acc, val_tpr, val_f1, val_loss, output_summary = validate(test_loader, model, criterion, summary_output=True)
    
    scheduler.step(val_loss)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_mcc = val_mcc
        counter = 0

        save_dir = "CustomModel2"
        os.makedirs(save_dir, exist_ok=True)
        save_path = os.path.join(save_dir, "best_model.pth")

        torch.save(model.state_dict(), save_path)
    
    else:
        counter += 1
        if counter >= patience:
            print("Early stopping triggered")
            break

    print(f"Epoch {epoch+1}/{num_epochs}")
    print(f"Train Loss: {train_loss:.4f}, Train MCC: {train_mcc:.4f}")
    print(f"Validation Loss: {val_loss:.4f}, Validation MCC: {val_mcc:.4f}, ACC: {val_acc:.4f}, TPR: {val_tpr:.4f}, F1: {val_f1:.4f}")

print(f"Best MCC during training: {best_mcc:.4f}")
'''
# Out:
# '\ndevice = torch.device("cuda" if torch.cuda.is_available() else "cpu")\nmodel = CustomModel2().to(device)\ncriterion = torch.nn.CrossEntropyLoss()\noptimizer = optim.AdamW(model.parameters(), lr=0.001, weight_decay=0.01)\n\nnum_epochs = 20\npatience = 10  # Số epoch để chờ trước khi dừng\ncounter = 0\n\nscheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode=\'min\', factor=0.5, patience=5)\n\nbest_val_loss = float(\'inf\')\nbest_mcc = -1  # Khởi tạo MCC tốt nhất\n\nfor epoch in range(num_epochs):\n    train_mcc, train_loss = train(train_loader, model, criterion, optimizer, epoch)\n\n    val_mcc, val_acc, val_tpr, val_f1, val_loss, output_summary = validate(test_loader, model, criterion, summary_output=True)\n    \n    scheduler.step(val_loss)\n\n    if val_loss < best_val_loss:\n        best_val_loss = val_loss\n        best_mcc = val_mcc\n        counter = 0\n\n        save_dir = "CustomModel2"\n        os.makedirs(save_dir, exist_ok=True)\n        save_path = os.path.join(save_dir, "best_model.pth")\n\n        torch.save(model.state_dict(), save_path)\n    \n    else:\n        counter += 1\n        if counter >= patience:\n            print("Early stopping triggered")\n            break\n\n    print(f"Epoch {epoch+1}/{num_epochs}")\n    print(f"Train Loss: {train_loss:.4f}, Train MCC: {train_mcc:.4f}")\n    print(f"Validation Loss: {val_loss:.4f}, Validation MCC: {val_mcc:.4f}, ACC: {val_acc:.4f}, TPR: {val_tpr:.4f}, F1: {val_f1:.4f}")\n\nprint(f"Best MCC during training: {best_mcc:.4f}")\n'

# %% [markdown]
# ## Attack second model

# %%
model_path = os.path.join("CustomModel2", "best_model.pth")
if not os.path.exists(model_path):
    raise FileNotFoundError(f"Không tìm thấy mô hình tại: {best_model_path}")

trained_model = CustomModel2()

trained_model.load_state_dict(torch.load(model_path, map_location=torch.device('cuda' if torch.cuda.is_available() else 'cpu')))
trained_model = trained_model.to(device)

# best_mcc = validate_score(trained_model, test_loader)
# print(f"MCC before attack: {best_mcc}")

results = validate_score(trained_model, test_loader)
print(f"MCC before attack: {round(results['MCC'], 5)}")
print(f"Accuracy before attack: {round(results['Accuracy'], 5)}")
print(f"TPR before attack: {round(results['TPR'], 5)}")
print(f"F1-score before attack: {round(results['F1 Score'], 5)}")
# Out:
# MCC before attack: 0.99796
# Accuracy before attack: 0.99973
# TPR before attack: 0.97985
# F1-score before attack: 0.97903

# %%
model_path = os.path.join("CustomModel2", "best_model.pth")

trained_model = CustomModel2()

trained_model.load_state_dict(torch.load(model_path, map_location=torch.device('cuda' if torch.cuda.is_available() else 'cpu')))
trained_model = trained_model.to(device)

model_clean = copy.deepcopy(trained_model)

attacker = BFA(criterion=criterion, model=trained_model, k_top=10)

# Định nghĩa đường dẫn để lưu kết quả tấn công
attack_dir = os.path.join("CustomModel2", "PBS_attack")

os.makedirs(attack_dir, exist_ok=True)
attack_image_paths = [os.path.join(attack_dir, f"{metric}_PBS_attack.png") 
                      for metric in ["MCC", "ACC", "TPR", "F1"]]
# attack_image_path = os.path.join(attack_dir, "PBS_attack.png")
attack_csv_path = os.path.join(attack_dir, "PBS_attack.csv")

perform_attack(
    attacker=attacker,               # Đối tượng tấn công
    model=trained_model,             # Mô hình bị tấn công
    model_clean=model_clean,         # Mô hình gốc làm tham chiếu
    train_loader=train_loader,       # Bộ dữ liệu huấn luyện
    test_loader=test_loader,         # Bộ dữ liệu kiểm tra
    N_iter=args.n_iter,              # Số vòng lặp tấn công
    writer=writer,                   # TensorBoard writer để ghi log
    file=attack_image_paths,          # Lưu ảnh vào thư mục tấn công
    csv_file=attack_csv_path,  
    csv_save_path=args.save_path,    # Đường dẫn lưu file CSV
    attack_type= 1,                  # Chế độ tấn công PBS
)

writer.close()  # Đóng TensorBoard writer
# best_mcc = validate_score(trained_model, test_loader)
# print(f"\nMCC after 100 times PBS: {best_mcc}")

results = validate_score(trained_model, test_loader)
print(f"MCC after 100 times PBS attack: {results['MCC']}")
print(f"Accuracy after 100 times PBS attack: {results['Accuracy']}")
print(f"TPR after 100 times PBS attack: {results['TPR']}")
print(f"F1-score after 100 times PBS attack: {results['F1 Score']}")
# Out:
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Attack sample size is 256
# **********************************
# attacked module: classifier
# Iteration: [001/025]   Attack Time 3.350 (3.350)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 100
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 3.537 (3.537)
# **********************************
# attacked module: classifier
# Iteration: [002/025]   Attack Time 3.340 (3.345)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 200
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 3.495 (3.516)
# **********************************
# attacked module: classifier
# Iteration: [003/025]   Attack Time 3.172 (3.287)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 300
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 3.451 (3.494)
# **********************************
# attacked module: classifier
# Iteration: [004/025]   Attack Time 3.349 (3.303)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 400
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 3.453 (3.484)
# **********************************
# attacked module: classifier
# Iteration: [005/025]   Attack Time 3.202 (3.283)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 500
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 3.505 (3.488)
# **********************************
# attacked module: classifier
# Iteration: [006/025]   Attack Time 3.262 (3.279)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 600
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 3.402 (3.474)
# **********************************
# attacked module: classifier
# Iteration: [007/025]   Attack Time 3.154 (3.261)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 700
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 3.570 (3.488)
# **********************************
# attacked module: classifier
# Iteration: [008/025]   Attack Time 3.300 (3.266)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 800
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 3.454 (3.483)
# **********************************
# attacked module: classifier
# Iteration: [009/025]   Attack Time 3.169 (3.255)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 900
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 3.470 (3.482)
# **********************************
# attacked module: classifier
# Iteration: [010/025]   Attack Time 3.212 (3.251)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 1000
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 3.434 (3.477)
# **********************************
# attacked module: classifier
# Iteration: [011/025]   Attack Time 3.268 (3.253)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 1100
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 3.478 (3.477)
# **********************************
# attacked module: classifier
# Iteration: [012/025]   Attack Time 3.147 (3.244)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 1200
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 3.341 (3.466)
# **********************************
# attacked module: classifier
# Iteration: [013/025]   Attack Time 3.150 (3.237)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 1300
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 3.408 (3.461)
# **********************************
# attacked module: classifier
# Iteration: [014/025]   Attack Time 3.227 (3.236)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 1400
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 3.381 (3.456)
# **********************************
# attacked module: classifier
# Iteration: [015/025]   Attack Time 3.249 (3.237)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 1500
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 3.583 (3.464)
# **********************************
# attacked module: classifier
# Iteration: [016/025]   Attack Time 3.238 (3.237)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 1600
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 3.358 (3.458)
# **********************************
# attacked module: classifier
# Iteration: [017/025]   Attack Time 3.206 (3.235)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 1700
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 3.397 (3.454)
# **********************************
# attacked module: classifier
# Iteration: [018/025]   Attack Time 3.215 (3.234)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 1800
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 3.317 (3.446)
# **********************************
# attacked module: classifier
# Iteration: [019/025]   Attack Time 3.198 (3.232)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 1900
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 3.486 (3.448)
# **********************************
# attacked module: classifier
# Iteration: [020/025]   Attack Time 3.098 (3.225)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 2000
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 3.386 (3.445)
# **********************************
# attacked module: classifier
# Iteration: [021/025]   Attack Time 3.181 (3.223)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 2100
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 3.347 (3.441)
# **********************************
# attacked module: classifier
# Iteration: [022/025]   Attack Time 3.291 (3.226)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 2200
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 3.391 (3.438)
# **********************************
# attacked module: classifier
# Iteration: [023/025]   Attack Time 3.189 (3.225)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 2300
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 3.361 (3.435)
# **********************************
# attacked module: classifier
# Iteration: [024/025]   Attack Time 3.248 (3.226)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 2400
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 3.407 (3.434)
# **********************************
# attacked module: classifier
# Iteration: [025/025]   Attack Time 3.194 (3.224)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 2500
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 3.377 (3.432)
# Plot saved as CustomModel2/PBS_attack/MCC_PBS_attack.png
# Plot saved as CustomModel2/PBS_attack/ACC_PBS_attack.png
# Plot saved as CustomModel2/PBS_attack/TPR_PBS_attack.png
# Plot saved as CustomModel2/PBS_attack/F1_PBS_attack.png
# [Combined Plot] Saved as CustomModel2/PBS_attack/combined_metrics_PBS_attack.png
# MCC after 100 times PBS attack: 0.9979639547094823
# Accuracy after 100 times PBS attack: 0.9997285714285714
# TPR after 100 times PBS attack: 0.9798526443768999
# F1-score after 100 times PBS attack: 0.9790333567727282

# %%
model_path = os.path.join("CustomModel2", "best_model.pth")
trained_model = CustomModel2()

trained_model.load_state_dict(torch.load(model_path, map_location=torch.device('cuda' if torch.cuda.is_available() else 'cpu')))
trained_model = trained_model.to(device)

# Bước 2: Tạo bản sao của mô hình để làm tham chiếu
model_clean = copy.deepcopy(trained_model)

# Bước 3: Khởi tạo đối tượng tấn công BFA
attacker = BFA(criterion=criterion, model=trained_model, k_top=10)

# Định nghĩa đường dẫn để lưu kết quả tấn công
attack_dir = os.path.join("CustomModel2", "RandomFlip_attack")

os.makedirs(attack_dir, exist_ok=True)
attack_image_paths = [os.path.join(attack_dir, f"{metric}_RandomFlip_attack.png") 
                      for metric in ["MCC", "ACC", "TPR", "F1"]]
# attack_image_path = os.path.join(attack_dir, "RandomFlip_attack.png")
attack_csv_path = os.path.join(attack_dir, "RandomFlip_attack.csv")

# Bước 4: Thực hiện tấn công
perform_attack(
    attacker=attacker,               # Đối tượng tấn công
    model=trained_model,             # Mô hình bị tấn công
    model_clean=model_clean,         # Mô hình gốc làm tham chiếu
    train_loader=train_loader,       # Bộ dữ liệu huấn luyện
    test_loader=test_loader,         # Bộ dữ liệu kiểm tra
    N_iter=args.n_iter,              # Số vòng lặp tấn công
    writer=writer,                   # TensorBoard writer để ghi log
    file=attack_image_paths,          # Lưu ảnh vào thư mục tấn công
    csv_file=attack_csv_path, 
    csv_save_path=args.save_path,    # Đường dẫn lưu file CSV
    attack_type= 2,                  # Chế độ tấn công random
)

writer.close()  # Đóng TensorBoard writer

# best_mcc = validate_score(trained_model ,test_loader)
# print(f"\nMCC after 100 times Random attack: {best_mcc}")

results = validate_score(trained_model, test_loader)
print(f"MCC after 100 times random attack: {results['MCC']}")
print(f"Accuracy after 100 times random attack: {results['Accuracy']}")
print(f"TPR after 100 times random attack: {results['TPR']}")
print(f"F1-score after 100 times random attack: {results['F1 Score']}")
# Out:
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Attack sample size is 256
# **********************************
# attacked module: classifier
# attacked weight index: 380
# weight before attack: tensor(-0.0113, device='cuda:0')
# weight after attack: tensor(32767., device='cuda:0')
# Iteration: [001/025]   Attack Time 3.139 (3.139)
# Bit flips: 1
# Hamming distance: 0
# **Test** MCC: -0.044. Val_Loss: 1.885
# ACC: 0.000.
# TPR: 0.009.
# F1-score: 0.001.
# Iteration Time 3.402 (3.402)
# **********************************
# attacked module: classifier
# attacked weight index: 303
# weight before attack: tensor(0.0535, device='cuda:0')
# weight after attack: tensor(1024., device='cuda:0')
# Iteration: [002/025]   Attack Time 3.097 (3.118)
# Bit flips: 2
# Hamming distance: 0
# **Test** MCC: -0.044. Val_Loss: 1.885
# ACC: 0.000.
# TPR: 0.009.
# F1-score: 0.001.
# Iteration Time 3.545 (3.474)
# **********************************
# attacked module: classifier
# attacked weight index: 138
# weight before attack: tensor(-0.0559, device='cuda:0')
# weight after attack: tensor(-3., device='cuda:0')
# Iteration: [003/025]   Attack Time 3.145 (3.127)
# Bit flips: 3
# Hamming distance: 0
# **Test** MCC: -0.044. Val_Loss: 1.884
# ACC: 0.000.
# TPR: 0.009.
# F1-score: 0.001.
# Iteration Time 3.505 (3.484)
# **********************************
# attacked module: classifier
# attacked weight index: 109
# weight before attack: tensor(-0.0250, device='cuda:0')
# weight after attack: tensor(-9., device='cuda:0')
# Iteration: [004/025]   Attack Time 3.141 (3.130)
# Bit flips: 4
# Hamming distance: 0
# **Test** MCC: -0.044. Val_Loss: 1.884
# ACC: 0.000.
# TPR: 0.009.
# F1-score: 0.001.
# Iteration Time 3.463 (3.479)
# **********************************
# attacked module: classifier
# attacked weight index: 216
# weight before attack: tensor(-0.0220, device='cuda:0')
# weight after attack: tensor(-5., device='cuda:0')
# Iteration: [005/025]   Attack Time 3.139 (3.132)
# Bit flips: 5
# Hamming distance: 0
# **Test** MCC: -0.044. Val_Loss: 1.884
# ACC: 0.000.
# TPR: 0.009.
# F1-score: 0.001.
# Iteration Time 3.515 (3.486)
# **********************************
# attacked module: classifier
# attacked weight index: 417
# weight before attack: tensor(-0.0365, device='cuda:0')
# weight after attack: tensor(-2., device='cuda:0')
# Iteration: [006/025]   Attack Time 3.100 (3.127)
# Bit flips: 6
# Hamming distance: 0
# **Test** MCC: -0.044. Val_Loss: 1.884
# ACC: 0.000.
# TPR: 0.009.
# F1-score: 0.001.
# Iteration Time 3.450 (3.480)
# **********************************
# attacked module: classifier
# attacked weight index: 485
# weight before attack: tensor(0.0688, device='cuda:0')
# weight after attack: tensor(512., device='cuda:0')
# Iteration: [007/025]   Attack Time 3.162 (3.132)
# Bit flips: 7
# Hamming distance: 0
# **Test** MCC: -0.089. Val_Loss: 1.886
# ACC: 0.000.
# TPR: 0.008.
# F1-score: 0.001.
# Iteration Time 3.412 (3.470)
# **********************************
# attacked module: classifier
# attacked weight index: 376
# weight before attack: tensor(-0.0595, device='cuda:0')
# weight after attack: tensor(-9., device='cuda:0')
# Iteration: [008/025]   Attack Time 3.127 (3.131)
# Bit flips: 8
# Hamming distance: 0
# **Test** MCC: -0.089. Val_Loss: 1.884
# ACC: 0.000.
# TPR: 0.008.
# F1-score: 0.001.
# Iteration Time 3.419 (3.464)
# **********************************
# attacked module: classifier
# attacked weight index: 226
# weight before attack: tensor(-0.0384, device='cuda:0')
# weight after attack: tensor(-8193., device='cuda:0')
# Iteration: [009/025]   Attack Time 3.101 (3.128)
# Bit flips: 9
# Hamming distance: 0
# **Test** MCC: -0.089. Val_Loss: 1.884
# ACC: 0.000.
# TPR: 0.008.
# F1-score: 0.001.
# Iteration Time 3.273 (3.443)
# **********************************
# attacked module: classifier
# attacked weight index: 248
# weight before attack: tensor(0.0473, device='cuda:0')
# weight after attack: tensor(1., device='cuda:0')
# Iteration: [010/025]   Attack Time 3.019 (3.117)
# Bit flips: 10
# Hamming distance: 0
# **Test** MCC: 0.363. Val_Loss: 1.838
# ACC: 0.067.
# TPR: 0.333.
# F1-score: 0.332.
# Iteration Time 3.367 (3.435)
# **********************************
# attacked module: classifier
# attacked weight index: 101
# weight before attack: tensor(-0.0479, device='cuda:0')
# weight after attack: tensor(-257., device='cuda:0')
# Iteration: [011/025]   Attack Time 3.135 (3.119)
# Bit flips: 11
# Hamming distance: 0
# **Test** MCC: 0.363. Val_Loss: 1.838
# ACC: 0.067.
# TPR: 0.333.
# F1-score: 0.332.
# Iteration Time 3.559 (3.447)
# **********************************
# attacked module: classifier
# attacked weight index: 329
# weight before attack: tensor(-0.0097, device='cuda:0')
# weight after attack: tensor(-9., device='cuda:0')
# Iteration: [012/025]   Attack Time 3.143 (3.121)
# Bit flips: 12
# Hamming distance: 0
# **Test** MCC: 0.363. Val_Loss: 1.838
# ACC: 0.067.
# TPR: 0.333.
# F1-score: 0.332.
# Iteration Time 3.539 (3.454)
# **********************************
# attacked module: classifier
# attacked weight index: 16
# weight before attack: tensor(0.0547, device='cuda:0')
# weight after attack: tensor(2048., device='cuda:0')
# Iteration: [013/025]   Attack Time 3.111 (3.120)
# Bit flips: 13
# Hamming distance: 0
# **Test** MCC: 0.363. Val_Loss: 1.838
# ACC: 0.067.
# TPR: 0.333.
# F1-score: 0.332.
# Iteration Time 3.548 (3.461)
# **********************************
# attacked module: classifier
# attacked weight index: 469
# weight before attack: tensor(0.0430, device='cuda:0')
# weight after attack: tensor(64., device='cuda:0')
# Iteration: [014/025]   Attack Time 3.177 (3.124)
# Bit flips: 14
# Hamming distance: 0
# **Test** MCC: 0.360. Val_Loss: 1.839
# ACC: 0.066.
# TPR: 0.325.
# F1-score: 0.324.
# Iteration Time 3.471 (3.462)
# **********************************
# attacked module: classifier
# attacked weight index: 311
# weight before attack: tensor(-0.0251, device='cuda:0')
# weight after attack: tensor(-9., device='cuda:0')
# Iteration: [015/025]   Attack Time 3.163 (3.127)
# Bit flips: 15
# Hamming distance: 0
# **Test** MCC: 0.360. Val_Loss: 1.839
# ACC: 0.066.
# TPR: 0.325.
# F1-score: 0.324.
# Iteration Time 3.552 (3.468)
# **********************************
# attacked module: classifier
# attacked weight index: 461
# weight before attack: tensor(-0.0274, device='cuda:0')
# weight after attack: tensor(-2049., device='cuda:0')
# Iteration: [016/025]   Attack Time 3.139 (3.127)
# Bit flips: 16
# Hamming distance: 0
# **Test** MCC: 0.360. Val_Loss: 1.839
# ACC: 0.066.
# TPR: 0.325.
# F1-score: 0.324.
# Iteration Time 3.513 (3.471)
# **********************************
# attacked module: classifier
# attacked weight index: 270
# weight before attack: tensor(-0.0369, device='cuda:0')
# weight after attack: tensor(-5., device='cuda:0')
# Iteration: [017/025]   Attack Time 3.190 (3.131)
# Bit flips: 17
# Hamming distance: 0
# **Test** MCC: 0.360. Val_Loss: 1.839
# ACC: 0.066.
# TPR: 0.325.
# F1-score: 0.324.
# Iteration Time 3.478 (3.471)
# **********************************
# attacked module: classifier
# attacked weight index: 410
# weight before attack: tensor(-0.0651, device='cuda:0')
# weight after attack: tensor(-16385., device='cuda:0')
# Iteration: [018/025]   Attack Time 3.198 (3.135)
# Bit flips: 18
# Hamming distance: 0
# **Test** MCC: 0.360. Val_Loss: 1.839
# ACC: 0.066.
# TPR: 0.325.
# F1-score: 0.324.
# Iteration Time 3.460 (3.471)
# **********************************
# attacked module: classifier
# attacked weight index: 330
# weight before attack: tensor(0.0191, device='cuda:0')
# weight after attack: tensor(16384., device='cuda:0')
# Iteration: [019/025]   Attack Time 3.164 (3.136)
# Bit flips: 19
# Hamming distance: 0
# **Test** MCC: 0.360. Val_Loss: 1.839
# ACC: 0.066.
# TPR: 0.325.
# F1-score: 0.324.
# Iteration Time 3.588 (3.477)
# **********************************
# attacked module: classifier
# attacked weight index: 23
# weight before attack: tensor(0.0701, device='cuda:0')
# weight after attack: tensor(4., device='cuda:0')
# Iteration: [020/025]   Attack Time 3.134 (3.136)
# Bit flips: 20
# Hamming distance: 0
# **Test** MCC: 0.360. Val_Loss: 1.839
# ACC: 0.066.
# TPR: 0.325.
# F1-score: 0.324.
# Iteration Time 3.483 (3.477)
# **********************************
# attacked module: classifier
# attacked weight index: 205
# weight before attack: tensor(-0.0441, device='cuda:0')
# weight after attack: tensor(-513., device='cuda:0')
# Iteration: [021/025]   Attack Time 3.128 (3.136)
# Bit flips: 21
# Hamming distance: 0
# **Test** MCC: 0.359. Val_Loss: 1.839
# ACC: 0.066.
# TPR: 0.322.
# F1-score: 0.322.
# Iteration Time 3.513 (3.479)
# **********************************
# attacked module: classifier
# attacked weight index: 252
# weight before attack: tensor(0.0044, device='cuda:0')
# weight after attack: tensor(2., device='cuda:0')
# Iteration: [022/025]   Attack Time 3.117 (3.135)
# Bit flips: 22
# Hamming distance: 0
# **Test** MCC: 0.359. Val_Loss: 1.839
# ACC: 0.066.
# TPR: 0.322.
# F1-score: 0.322.
# Iteration Time 3.598 (3.484)
# **********************************
# attacked module: classifier
# attacked weight index: 9
# weight before attack: tensor(0.0610, device='cuda:0')
# weight after attack: tensor(4096., device='cuda:0')
# Iteration: [023/025]   Attack Time 3.112 (3.134)
# Bit flips: 23
# Hamming distance: 0
# **Test** MCC: 0.404. Val_Loss: 1.839
# ACC: 0.066.
# TPR: 0.260.
# F1-score: 0.260.
# Iteration Time 3.473 (3.484)
# **********************************
# attacked module: classifier
# attacked weight index: 54
# weight before attack: tensor(-0.0046, device='cuda:0')
# weight after attack: tensor(-9., device='cuda:0')
# Iteration: [024/025]   Attack Time 3.243 (3.138)
# Bit flips: 24
# Hamming distance: 0
# **Test** MCC: 0.404. Val_Loss: 1.839
# ACC: 0.066.
# TPR: 0.260.
# F1-score: 0.260.
# Iteration Time 3.575 (3.488)
# **********************************
# attacked module: classifier
# attacked weight index: 398
# weight before attack: tensor(-0.0678, device='cuda:0')
# weight after attack: tensor(32767., device='cuda:0')
# Iteration: [025/025]   Attack Time 3.167 (3.140)
# Bit flips: 25
# Hamming distance: 0
# **Test** MCC: 0.405. Val_Loss: 1.839
# ACC: 0.066.
# TPR: 0.260.
# F1-score: 0.260.
# Iteration Time 3.500 (3.488)
# Plot saved as CustomModel2/RandomFlip_attack/MCC_RandomFlip_attack.png
# Plot saved as CustomModel2/RandomFlip_attack/ACC_RandomFlip_attack.png
# Plot saved as CustomModel2/RandomFlip_attack/TPR_RandomFlip_attack.png
# Plot saved as CustomModel2/RandomFlip_attack/F1_RandomFlip_attack.png
# [Combined Plot] Saved as CustomModel2/RandomFlip_attack/combined_metrics_RandomFlip_attack.png
# MCC after 100 times random attack: 0.40450853432843586
# Accuracy after 100 times random attack: 0.06619285714285714
# TPR after 100 times random attack: 0.26011917494270426
# F1-score after 100 times random attack: 0.2603106760374363

# %%
model_path = os.path.join("CustomModel2", "best_model.pth")
if not os.path.exists(model_path):
    raise FileNotFoundError(f"Không tìm thấy mô hình tại: {model_path}")

trained_model = CustomModel2()

trained_model.load_state_dict(torch.load(model_path, map_location=torch.device('cuda' if torch.cuda.is_available() else 'cpu')))
trained_model = trained_model.to(device)


# Bước 2: Tạo bản sao của mô hình để làm tham chiếu
model_clean = copy.deepcopy(trained_model)

# Bước 3: Khởi tạo đối tượng tấn công BFA
attacker = BFA(criterion=criterion, model=trained_model, k_top=10)

# Định nghĩa đường dẫn để lưu kết quả tấn công
attack_dir = os.path.join("CustomModel2", "PBS_to_RandomFlip_attack")

os.makedirs(attack_dir, exist_ok=True)
attack_image_paths = [os.path.join(attack_dir, f"{metric}_PBS_to_RandomFlip_attack.png") 
                      for metric in ["MCC", "ACC", "TPR", "F1"]]
# attack_image_path = os.path.join(attack_dir, "PBS_to_RandomFlip_attack.png")
attack_csv_path = os.path.join(attack_dir, "PBS_to_RandomFlip_attack.csv")

# Bước 4: Thực hiện tấn công
perform_attack(
    attacker=attacker,               # Đối tượng tấn công
    model=trained_model,             # Mô hình bị tấn công
    model_clean=model_clean,         # Mô hình gốc làm tham chiếu
    train_loader=train_loader,       # Bộ dữ liệu huấn luyện
    test_loader=test_loader,         # Bộ dữ liệu kiểm tra
    N_iter=args.n_iter,              # Số vòng lặp tấn công
    writer=writer,                   # TensorBoard writer để ghi log
    file=attack_image_paths,          # Lưu ảnh vào thư mục tấn công
    csv_file=attack_csv_path, 
    csv_save_path=args.save_path,    # Đường dẫn lưu file CSV
    attack_type= 3,                  # Chế độ tấn công PBS -> random
)

writer.close()  # Đóng TensorBoard writer
# best_mcc = validate_score( trained_model,test_loader)
# print(f"\nMCC after 100 times PBS to Random: {best_mcc}")

results = validate_score(trained_model, test_loader)
print(f"MCC after 100 times PBS to Random: {results['MCC']}")
print(f"Accuracy after 100 times PBS to Random: {results['Accuracy']}")
print(f"TPR after 100 times PBS to Random: {results['TPR']}")
print(f"F1-score after 100 times PBS to Random: {results['F1 Score']}")
# Out:
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Attack sample size is 256
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 12
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(8., device='cuda:0')
# Iteration: [001/025]   Attack Time 6.422 (6.422)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 101
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.978.
# F1-score: 0.977.
# Iteration Time 3.400 (3.400)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 11
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(32., device='cuda:0')
# Iteration: [002/025]   Attack Time 6.311 (6.367)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 202
# Hamming distance: 0
# **Test** MCC: 0.545. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.470.
# F1-score: 0.462.
# Iteration Time 3.546 (3.473)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 56
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(2048., device='cuda:0')
# Iteration: [003/025]   Attack Time 6.471 (6.401)
# Loss before attack: 0.9556
# Loss after attack: 0.9556
# Bit flips: 303
# Hamming distance: 0
# **Test** MCC: 0.134. Val_Loss: 1.898
# ACC: 0.007.
# TPR: 0.209.
# F1-score: 0.199.
# Iteration Time 3.440 (3.462)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 318
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(4., device='cuda:0')
# Iteration: [004/025]   Attack Time 6.365 (6.392)
# Loss before attack: 1.9009
# Loss after attack: 1.9009
# Bit flips: 404
# Hamming distance: 0
# **Test** MCC: 0.134. Val_Loss: 1.898
# ACC: 0.007.
# TPR: 0.209.
# F1-score: 0.199.
# Iteration Time 3.588 (3.494)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 275
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-3., device='cuda:0')
# Iteration: [005/025]   Attack Time 6.267 (6.367)
# Loss before attack: 1.9009
# Loss after attack: 1.9009
# Bit flips: 505
# Hamming distance: 0
# **Test** MCC: 0.134. Val_Loss: 1.898
# ACC: 0.007.
# TPR: 0.209.
# F1-score: 0.199.
# Iteration Time 3.496 (3.494)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 309
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(2048., device='cuda:0')
# Iteration: [006/025]   Attack Time 6.404 (6.373)
# Loss before attack: 1.9009
# Loss after attack: 1.9009
# Bit flips: 606
# Hamming distance: 0
# **Test** MCC: 0.135. Val_Loss: 1.898
# ACC: 0.007.
# TPR: 0.211.
# F1-score: 0.201.
# Iteration Time 3.281 (3.459)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 336
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-9., device='cuda:0')
# Iteration: [007/025]   Attack Time 8.132 (6.625)
# Loss before attack: 1.9009
# Loss after attack: 1.9009
# Bit flips: 707
# Hamming distance: 0
# **Test** MCC: 0.135. Val_Loss: 1.898
# ACC: 0.007.
# TPR: 0.211.
# F1-score: 0.201.
# Iteration Time 3.397 (3.450)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 460
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-65., device='cuda:0')
# Iteration: [008/025]   Attack Time 6.254 (6.578)
# Loss before attack: 1.9009
# Loss after attack: 1.9009
# Bit flips: 808
# Hamming distance: 0
# **Test** MCC: 0.135. Val_Loss: 1.898
# ACC: 0.007.
# TPR: 0.211.
# F1-score: 0.201.
# Iteration Time 3.419 (3.446)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 119
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(16384., device='cuda:0')
# Iteration: [009/025]   Attack Time 6.349 (6.553)
# Loss before attack: 1.9009
# Loss after attack: 1.9009
# Bit flips: 909
# Hamming distance: 0
# **Test** MCC: 0.135. Val_Loss: 1.898
# ACC: 0.007.
# TPR: 0.218.
# F1-score: 0.208.
# Iteration Time 3.425 (3.444)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 64
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-33., device='cuda:0')
# Iteration: [010/025]   Attack Time 6.446 (6.542)
# Loss before attack: 1.9009
# Loss after attack: 1.9009
# Bit flips: 1010
# Hamming distance: 0
# **Test** MCC: 0.135. Val_Loss: 1.898
# ACC: 0.007.
# TPR: 0.218.
# F1-score: 0.208.
# Iteration Time 3.412 (3.440)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 119
# weight before attack: tensor(16384., device='cuda:0')
# weight after attack: tensor(16388., device='cuda:0')
# Iteration: [011/025]   Attack Time 6.384 (6.528)
# Loss before attack: 1.9009
# Loss after attack: 1.9009
# Bit flips: 1111
# Hamming distance: 0
# **Test** MCC: 0.135. Val_Loss: 1.898
# ACC: 0.007.
# TPR: 0.218.
# F1-score: 0.208.
# Iteration Time 3.282 (3.426)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 79
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(16., device='cuda:0')
# Iteration: [012/025]   Attack Time 6.372 (6.515)
# Loss before attack: 1.9009
# Loss after attack: 1.9009
# Bit flips: 1212
# Hamming distance: 0
# **Test** MCC: 0.135. Val_Loss: 1.898
# ACC: 0.007.
# TPR: 0.218.
# F1-score: 0.208.
# Iteration Time 3.499 (3.432)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 294
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-2049., device='cuda:0')
# Iteration: [013/025]   Attack Time 6.137 (6.486)
# Loss before attack: 1.9009
# Loss after attack: 1.9009
# Bit flips: 1313
# Hamming distance: 0
# **Test** MCC: 0.135. Val_Loss: 1.898
# ACC: 0.007.
# TPR: 0.218.
# F1-score: 0.208.
# Iteration Time 3.443 (3.433)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 119
# weight before attack: tensor(16388., device='cuda:0')
# weight after attack: tensor(4., device='cuda:0')
# Iteration: [014/025]   Attack Time 6.249 (6.469)
# Loss before attack: 1.9009
# Loss after attack: 1.9009
# Bit flips: 1414
# Hamming distance: 0
# **Test** MCC: 0.134. Val_Loss: 1.898
# ACC: 0.007.
# TPR: 0.211.
# F1-score: 0.199.
# Iteration Time 3.438 (3.433)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 451
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(16., device='cuda:0')
# Iteration: [015/025]   Attack Time 6.202 (6.451)
# Loss before attack: 1.9009
# Loss after attack: 1.9009
# Bit flips: 1515
# Hamming distance: 0
# **Test** MCC: 0.134. Val_Loss: 1.898
# ACC: 0.007.
# TPR: 0.211.
# F1-score: 0.199.
# Iteration Time 3.368 (3.429)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 106
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(1., device='cuda:0')
# Iteration: [016/025]   Attack Time 6.561 (6.458)
# Loss before attack: 1.9009
# Loss after attack: 1.9009
# Bit flips: 1616
# Hamming distance: 0
# **Test** MCC: 0.134. Val_Loss: 1.898
# ACC: 0.007.
# TPR: 0.211.
# F1-score: 0.199.
# Iteration Time 3.389 (3.427)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 106
# weight before attack: tensor(1., device='cuda:0')
# weight after attack: tensor(8193., device='cuda:0')
# Iteration: [017/025]   Attack Time 6.467 (6.458)
# Loss before attack: 1.9009
# Loss after attack: 1.9009
# Bit flips: 1717
# Hamming distance: 0
# **Test** MCC: 0.001. Val_Loss: 1.905
# ACC: 0.000.
# TPR: 0.012.
# F1-score: 0.001.
# Iteration Time 3.364 (3.423)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 410
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(32767., device='cuda:0')
# Iteration: [018/025]   Attack Time 6.489 (6.460)
# Loss before attack: 1.9048
# Loss after attack: 1.9048
# Bit flips: 1818
# Hamming distance: 0
# **Test** MCC: 0.001. Val_Loss: 1.905
# ACC: 0.000.
# TPR: 0.012.
# F1-score: 0.001.
# Iteration Time 3.404 (3.422)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 490
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(512., device='cuda:0')
# Iteration: [019/025]   Attack Time 6.382 (6.456)
# Loss before attack: 1.9048
# Loss after attack: 1.9048
# Bit flips: 1919
# Hamming distance: 0
# **Test** MCC: -0.000. Val_Loss: 1.905
# ACC: 0.000.
# TPR: 0.010.
# F1-score: 0.001.
# Iteration Time 3.379 (3.420)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 48
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-3., device='cuda:0')
# Iteration: [020/025]   Attack Time 6.381 (6.452)
# Loss before attack: 1.9048
# Loss after attack: 1.9048
# Bit flips: 2020
# Hamming distance: 0
# **Test** MCC: -0.000. Val_Loss: 1.905
# ACC: 0.000.
# TPR: 0.010.
# F1-score: 0.001.
# Iteration Time 3.426 (3.420)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 183
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(64., device='cuda:0')
# Iteration: [021/025]   Attack Time 6.396 (6.450)
# Loss before attack: 1.9048
# Loss after attack: 1.9048
# Bit flips: 2121
# Hamming distance: 0
# **Test** MCC: -0.000. Val_Loss: 1.905
# ACC: 0.000.
# TPR: 0.010.
# F1-score: 0.001.
# Iteration Time 3.520 (3.425)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 359
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(-32768., device='cuda:0')
# Iteration: [022/025]   Attack Time 6.732 (6.462)
# Loss before attack: 1.9048
# Loss after attack: 1.9048
# Bit flips: 2222
# Hamming distance: 0
# **Test** MCC: -0.000. Val_Loss: 1.905
# ACC: 0.000.
# TPR: 0.010.
# F1-score: 0.001.
# Iteration Time 3.543 (3.430)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 364
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(4., device='cuda:0')
# Iteration: [023/025]   Attack Time 6.157 (6.449)
# Loss before attack: 1.9048
# Loss after attack: 1.9048
# Bit flips: 2323
# Hamming distance: 0
# **Test** MCC: -0.000. Val_Loss: 1.905
# ACC: 0.000.
# TPR: 0.010.
# F1-score: 0.001.
# Iteration Time 3.379 (3.428)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 36
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-33., device='cuda:0')
# Iteration: [024/025]   Attack Time 6.357 (6.445)
# Loss before attack: 1.9048
# Loss after attack: 1.9048
# Bit flips: 2424
# Hamming distance: 0
# **Test** MCC: -0.000. Val_Loss: 1.905
# ACC: 0.000.
# TPR: 0.010.
# F1-score: 0.001.
# Iteration Time 3.425 (3.428)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 494
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-257., device='cuda:0')
# Iteration: [025/025]   Attack Time 6.265 (6.438)
# Loss before attack: 1.9048
# Loss after attack: 1.9048
# Bit flips: 2525
# Hamming distance: 0
# **Test** MCC: -0.000. Val_Loss: 1.905
# ACC: 0.000.
# TPR: 0.010.
# F1-score: 0.001.
# Iteration Time 3.552 (3.433)
# Plot saved as CustomModel2/PBS_to_RandomFlip_attack/MCC_PBS_to_RandomFlip_attack.png
# Plot saved as CustomModel2/PBS_to_RandomFlip_attack/ACC_PBS_to_RandomFlip_attack.png
# Plot saved as CustomModel2/PBS_to_RandomFlip_attack/TPR_PBS_to_RandomFlip_attack.png
# Plot saved as CustomModel2/PBS_to_RandomFlip_attack/F1_PBS_to_RandomFlip_attack.png
# [Combined Plot] Saved as CustomModel2/PBS_to_RandomFlip_attack/combined_metrics_PBS_to_RandomFlip_attack.png
# MCC after 100 times PBS to Random: -0.00037980223028249646
# Accuracy after 100 times PBS to Random: 0.00019285714285714286
# TPR after 100 times PBS to Random: 0.010102857142857146
# F1-score after 100 times PBS to Random: 0.0010088020348247052

# %%
# Bước 1: Tải mô hình đã huấn luyện
model_path = os.path.join("CustomModel2", "best_model.pth")
if not os.path.exists(model_path):
    raise FileNotFoundError(f"Không tìm thấy mô hình tại: {model_path}")

trained_model = CustomModel2()

trained_model.load_state_dict(torch.load(model_path, map_location=torch.device('cuda' if torch.cuda.is_available() else 'cpu')))
trained_model = trained_model.to(device)

# Bước 2: Tạo bản sao của mô hình để làm tham chiếu
model_clean = copy.deepcopy(trained_model)

# Bước 3: Khởi tạo đối tượng tấn công BFA
attacker = BFA(criterion=criterion, model=trained_model, k_top=10)

# Định nghĩa đường dẫn để lưu kết quả tấn công
attack_dir = os.path.join("CustomModel2", "RandomFlip_to_PBS_attack")

os.makedirs(attack_dir, exist_ok=True)
attack_image_paths = [os.path.join(attack_dir, f"{metric}_RandomFlip_to_PBS_attack.png") 
                      for metric in ["MCC", "ACC", "TPR", "F1"]]
# attack_image_path = os.path.join(attack_dir, "RandomFlip_to_PBS_attack.png")
attack_csv_path = os.path.join(attack_dir, "RandomFlip_to_PBS_attack.csv")

# Bước 4: Thực hiện tấn công
perform_attack(
    attacker=attacker,               # Đối tượng tấn công
    model=trained_model,             # Mô hình bị tấn công
    model_clean=model_clean,         # Mô hình gốc làm tham chiếu
    train_loader=train_loader,       # Bộ dữ liệu huấn luyện
    test_loader=test_loader,         # Bộ dữ liệu kiểm tra
    N_iter=args.n_iter,              # Số vòng lặp tấn công
    writer=writer,                   # TensorBoard writer để ghi log
    file=attack_image_paths,          # Lưu ảnh vào thư mục tấn công
    csv_file=attack_csv_path,  
    csv_save_path=args.save_path,    # Đường dẫn lưu file CSV
    attack_type= 4,                  # Chế độ tấn công Random -> PBS
)

writer.close()  # Đóng TensorBoard writer
# best_mcc = validate_score( trained_model,test_loader)
# print(f"\nMCC after 100 times Random to PBS: {best_mcc}")

results = validate_score(trained_model, test_loader)
print(f"MCC before attack: {round(results['MCC'], 5)}")
print(f"Accuracy before attack: {round(results['Accuracy'], 5)}")
print(f"TPR before attack: {round(results['TPR'], 5)}")
print(f"F1-score before attack: {round(results['F1 Score'], 5)}")
# Out:
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Attack sample size is 256
# **********************************
# attacked module: classifier
# attacked weight index: 149
# weight before attack: tensor(-0.0592, device='cuda:0')
# weight after attack: tensor(-9., device='cuda:0')
# attacked module: classifier
# Iteration: [001/025]   Attack Time 6.479 (6.479)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 101
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 3.493 (3.493)
# **********************************
# attacked module: classifier
# attacked weight index: 414
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-65., device='cuda:0')
# attacked module: classifier
# Iteration: [002/025]   Attack Time 6.161 (6.320)
# Loss before attack: 0.9087
# Loss after attack: 0.9087
# Bit flips: 202
# Hamming distance: 0
# **Test** MCC: 0.991. Val_Loss: 0.906
# ACC: 0.999.
# TPR: 0.969.
# F1-score: 0.953.
# Iteration Time 3.669 (3.581)
# **********************************
# attacked module: classifier
# attacked weight index: 480
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(4096., device='cuda:0')
# attacked module: classifier
# Iteration: [003/025]   Attack Time 6.579 (6.406)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 303
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 3.287 (3.483)
# **********************************
# attacked module: classifier
# attacked weight index: 86
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(2., device='cuda:0')
# attacked module: classifier
# Iteration: [004/025]   Attack Time 6.151 (6.342)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 404
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 3.420 (3.468)
# **********************************
# attacked module: classifier
# attacked weight index: 414
# weight before attack: tensor(-65., device='cuda:0')
# weight after attack: tensor(-16449., device='cuda:0')
# attacked module: classifier
# Iteration: [005/025]   Attack Time 6.268 (6.328)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 505
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 3.545 (3.483)
# **********************************
# attacked module: classifier
# attacked weight index: 85
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(4., device='cuda:0')
# attacked module: classifier
# Iteration: [006/025]   Attack Time 6.570 (6.368)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 606
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.979.
# F1-score: 0.979.
# Iteration Time 3.535 (3.492)
# **********************************
# attacked module: classifier
# attacked weight index: 425
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-5., device='cuda:0')
# attacked module: classifier
# Iteration: [007/025]   Attack Time 6.616 (6.403)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 707
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.979.
# F1-score: 0.979.
# Iteration Time 3.487 (3.491)
# **********************************
# attacked module: classifier
# attacked weight index: 311
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-9., device='cuda:0')
# attacked module: classifier
# Iteration: [008/025]   Attack Time 6.548 (6.421)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 808
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.979.
# F1-score: 0.979.
# Iteration Time 3.468 (3.488)
# **********************************
# attacked module: classifier
# attacked weight index: 428
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(16384., device='cuda:0')
# attacked module: classifier
# Iteration: [009/025]   Attack Time 6.337 (6.412)
# Loss before attack: 0.9595
# Loss after attack: 0.9595
# Bit flips: 909
# Hamming distance: 0
# **Test** MCC: 0.262. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.619.
# F1-score: 0.606.
# Iteration Time 3.538 (3.494)
# **********************************
# attacked module: classifier
# attacked weight index: 136
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-16385., device='cuda:0')
# attacked module: classifier
# Iteration: [010/025]   Attack Time 6.525 (6.423)
# Loss before attack: 0.9595
# Loss after attack: 0.9595
# Bit flips: 1010
# Hamming distance: 0
# **Test** MCC: 0.262. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.619.
# F1-score: 0.606.
# Iteration Time 3.398 (3.484)
# **********************************
# attacked module: classifier
# attacked weight index: 443
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-33., device='cuda:0')
# attacked module: classifier
# Iteration: [011/025]   Attack Time 6.351 (6.417)
# Loss before attack: 0.9595
# Loss after attack: 0.9595
# Bit flips: 1111
# Hamming distance: 0
# **Test** MCC: 0.262. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.619.
# F1-score: 0.606.
# Iteration Time 3.407 (3.477)
# **********************************
# attacked module: classifier
# attacked weight index: 288
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-5., device='cuda:0')
# attacked module: classifier
# Iteration: [012/025]   Attack Time 6.344 (6.411)
# Loss before attack: 0.9595
# Loss after attack: 0.9595
# Bit flips: 1212
# Hamming distance: 0
# **Test** MCC: 0.262. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.619.
# F1-score: 0.606.
# Iteration Time 3.363 (3.468)
# **********************************
# attacked module: classifier
# attacked weight index: 420
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-33., device='cuda:0')
# attacked module: classifier
# Iteration: [013/025]   Attack Time 6.491 (6.417)
# Loss before attack: 0.9595
# Loss after attack: 0.9595
# Bit flips: 1313
# Hamming distance: 0
# **Test** MCC: 0.262. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.619.
# F1-score: 0.606.
# Iteration Time 3.555 (3.474)
# **********************************
# attacked module: classifier
# attacked weight index: 446
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(8., device='cuda:0')
# attacked module: classifier
# Iteration: [014/025]   Attack Time 6.358 (6.413)
# Loss before attack: 0.9595
# Loss after attack: 0.9595
# Bit flips: 1414
# Hamming distance: 0
# **Test** MCC: 0.262. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.619.
# F1-score: 0.606.
# Iteration Time 3.381 (3.468)
# **********************************
# attacked module: classifier
# attacked weight index: 411
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-257., device='cuda:0')
# attacked module: classifier
# Iteration: [015/025]   Attack Time 6.307 (6.406)
# Loss before attack: 0.9595
# Loss after attack: 0.9595
# Bit flips: 1515
# Hamming distance: 0
# **Test** MCC: 0.262. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.619.
# F1-score: 0.606.
# Iteration Time 3.461 (3.467)
# **********************************
# attacked module: classifier
# attacked weight index: 479
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-9., device='cuda:0')
# attacked module: classifier
# Iteration: [016/025]   Attack Time 6.475 (6.410)
# Loss before attack: 0.9595
# Loss after attack: 0.9595
# Bit flips: 1616
# Hamming distance: 0
# **Test** MCC: 0.262. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.619.
# F1-score: 0.606.
# Iteration Time 3.533 (3.471)
# **********************************
# attacked module: classifier
# attacked weight index: 221
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(128., device='cuda:0')
# attacked module: classifier
# Iteration: [017/025]   Attack Time 6.376 (6.408)
# Loss before attack: 0.9595
# Loss after attack: 0.9595
# Bit flips: 1717
# Hamming distance: 0
# **Test** MCC: 0.262. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.619.
# F1-score: 0.606.
# Iteration Time 3.500 (3.473)
# **********************************
# attacked module: classifier
# attacked weight index: 389
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-1025., device='cuda:0')
# attacked module: classifier
# Iteration: [018/025]   Attack Time 6.368 (6.406)
# Loss before attack: 0.9595
# Loss after attack: 0.9595
# Bit flips: 1818
# Hamming distance: 0
# **Test** MCC: 0.262. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.619.
# F1-score: 0.606.
# Iteration Time 3.414 (3.470)
# **********************************
# attacked module: classifier
# attacked weight index: 455
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(2048., device='cuda:0')
# attacked module: classifier
# Iteration: [019/025]   Attack Time 6.422 (6.407)
# Loss before attack: 0.9595
# Loss after attack: 0.9595
# Bit flips: 1919
# Hamming distance: 0
# **Test** MCC: 0.263. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.619.
# F1-score: 0.606.
# Iteration Time 3.476 (3.470)
# **********************************
# attacked module: classifier
# attacked weight index: 484
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-33., device='cuda:0')
# attacked module: classifier
# Iteration: [020/025]   Attack Time 6.456 (6.409)
# Loss before attack: 0.9595
# Loss after attack: 0.9595
# Bit flips: 2020
# Hamming distance: 0
# **Test** MCC: 0.263. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.619.
# F1-score: 0.606.
# Iteration Time 3.586 (3.476)
# **********************************
# attacked module: classifier
# attacked weight index: 368
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(64., device='cuda:0')
# attacked module: classifier
# Iteration: [021/025]   Attack Time 6.468 (6.412)
# Loss before attack: 0.9595
# Loss after attack: 0.9595
# Bit flips: 2121
# Hamming distance: 0
# **Test** MCC: 0.263. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.619.
# F1-score: 0.606.
# Iteration Time 3.280 (3.466)
# **********************************
# attacked module: classifier
# attacked weight index: 449
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(32767., device='cuda:0')
# attacked module: classifier
# Iteration: [022/025]   Attack Time 6.123 (6.399)
# Loss before attack: 0.9595
# Loss after attack: 0.9595
# Bit flips: 2222
# Hamming distance: 0
# **Test** MCC: 0.263. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.619.
# F1-score: 0.606.
# Iteration Time 3.250 (3.457)
# **********************************
# attacked module: classifier
# attacked weight index: 190
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(128., device='cuda:0')
# attacked module: classifier
# Iteration: [023/025]   Attack Time 6.166 (6.389)
# Loss before attack: 0.9595
# Loss after attack: 0.9595
# Bit flips: 2323
# Hamming distance: 0
# **Test** MCC: 0.263. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.619.
# F1-score: 0.606.
# Iteration Time 3.474 (3.457)
# **********************************
# attacked module: classifier
# attacked weight index: 416
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-17., device='cuda:0')
# attacked module: classifier
# Iteration: [024/025]   Attack Time 6.377 (6.388)
# Loss before attack: 0.9595
# Loss after attack: 0.9595
# Bit flips: 2424
# Hamming distance: 0
# **Test** MCC: 0.263. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.619.
# F1-score: 0.606.
# Iteration Time 3.413 (3.456)
# **********************************
# attacked module: classifier
# attacked weight index: 140
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(2048., device='cuda:0')
# attacked module: classifier
# Iteration: [025/025]   Attack Time 6.574 (6.396)
# Loss before attack: 0.9595
# Loss after attack: 0.9595
# Bit flips: 2525
# Hamming distance: 0
# **Test** MCC: 0.263. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.619.
# F1-score: 0.606.
# Iteration Time 3.737 (3.467)
# Plot saved as CustomModel2/RandomFlip_to_PBS_attack/MCC_RandomFlip_to_PBS_attack.png
# Plot saved as CustomModel2/RandomFlip_to_PBS_attack/ACC_RandomFlip_to_PBS_attack.png
# Plot saved as CustomModel2/RandomFlip_to_PBS_attack/TPR_RandomFlip_to_PBS_attack.png
# Plot saved as CustomModel2/RandomFlip_to_PBS_attack/F1_RandomFlip_to_PBS_attack.png
# [Combined Plot] Saved as CustomModel2/RandomFlip_to_PBS_attack/combined_metrics_RandomFlip_to_PBS_attack.png
# MCC before attack: 0.2626
# Accuracy before attack: 0.93321
# TPR before attack: 0.61903
# F1-score before attack: 0.60636

# %%
model_names = ["CustomModel", "CustomModel2"]
attack_types = ["PBS", "RandomFlip", "PBS_to_RandomFlip", "RandomFlip_to_PBS"]

def aggregate_results(model_name, attack_types):
    
    aggregate_dir = os.path.join(model_name, "Aggregate_Results")
    os.makedirs(aggregate_dir, exist_ok=True)

    results = []

    # Đọc kết quả từ từng kịch bản tấn công
    for attack_type in attack_types:
        csv_file_path = os.path.join(model_name, f"{attack_type}_attack", f"{attack_type}_attack.csv")
        if os.path.exists(csv_file_path):
            df = pd.read_csv(csv_file_path)
            
            mcc_values = df['MCC'].tolist()
            results.append(mcc_values)
        else:
            print(f"File {csv_file_path} không tồn tại.")

    # Ghi kết quả tổng hợp vào file CSV
    aggregate_df = pd.DataFrame(results, index=attack_types).T
    aggregate_csv_path = os.path.join(aggregate_dir, "aggregated_results.csv")
    aggregate_df.to_csv(aggregate_csv_path)

    # Vẽ đồ thị so sánh
    plt.figure(figsize=(10, 6))
    for i, attack_type in enumerate(attack_types):
        plt.plot(aggregate_df.index, aggregate_df[attack_type], marker='o', label=attack_type)

    plt.title(f'So sánh MCC giữa các kịch bản tấn công cho {model_name}', fontsize=14)
    plt.xlabel('Epoch', fontsize=12)
    plt.ylabel('MCC', fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.legend()
    plt.tight_layout()

    epochs = aggregate_df.index.astype(int).tolist()
    plt.xticks(epochs, epochs)
    
    plot_path = os.path.join(aggregate_dir, f"{model_name}_comparison_plot.png")
    plt.savefig(plot_path)
    plt.close()
    print(f"Đồ thị đã được lưu tại {plot_path}")

for model_name in model_names:
    aggregate_results(model_name, attack_types)
# Out:
# Đồ thị đã được lưu tại CustomModel/Aggregate_Results/CustomModel_comparison_plot.png
# Đồ thị đã được lưu tại CustomModel2/Aggregate_Results/CustomModel2_comparison_plot.png

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")
sns.set_palette("husl")
plt.rcParams['font.family'] = 'DejaVu Sans, sans-serif'

def plot_attack_comparison_separate(model_names, attack_types):
    """Vẽ biểu đồ riêng biệt cho từng model, so sánh MCC giữa các phương pháp tấn công"""
    
    output_dir = "Comparative_Analysis"
    os.makedirs(output_dir, exist_ok=True)

    for model_name in model_names:
        aggregate_path = os.path.join(model_name, "Aggregate_Results", "aggregated_results.csv")
        if not os.path.exists(aggregate_path):
            print(f"Không tìm thấy file tổng hợp cho {model_name}")
            continue

        df = pd.read_csv(aggregate_path, index_col=0)

        # Chuẩn bị dữ liệu để vẽ
        df_melted = df.reset_index().melt(
            id_vars='index',
            value_vars=attack_types,
            var_name='Attack Type',
            value_name='MCC'
        )

        # Tạo một figure riêng cho từng model
        plt.figure(figsize=(10, 6))
        sns.lineplot(
            data=df_melted, x='index', y='MCC', hue='Attack Type',
            style='Attack Type', markers=True, dashes=False,
            linewidth=2.5, markersize=8, errorbar=None
        )

        # Tùy chỉnh biểu đồ
        plt.xlabel('Attack Iteration', fontsize=12)
        plt.ylabel('Matthews Correlation Coefficient', fontsize=12)
        plt.grid(True, linestyle='--', alpha=0.6)
        plt.legend(title='Attack Strategy', title_fontsize='12', fontsize=10)
        plt.xticks(ticks=range(int(df.index.min()), int(df.index.max()) + 1, 2))


        # Highlight MCC thấp nhất
        min_mcc = df[attack_types].min().min()
        plt.axhline(y=min_mcc, color='r', linestyle='--', alpha=0.5)
        plt.text(x=0, y=min_mcc + 0.05,
                 s=f'Min MCC: {min_mcc:.3f}',
                 color='r', fontsize=10)

        # Lưu hình
        output_path = os.path.join(output_dir, f"{model_name}_WUSTL_attack_comparison.png")
        plt.tight_layout()
        plt.savefig(output_path, dpi=300, bbox_inches='tight')
        plt.close()
        print(f"Đã lưu biểu đồ cho {model_name} tại: {output_path}")

# Gọi hàm
model_names = ["CustomModel", "CustomModel2"]
attack_types = ["PBS", "RandomFlip", "PBS_to_RandomFlip", "RandomFlip_to_PBS"]
plot_attack_comparison_separate(model_names, attack_types)
# Out:
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Đã lưu biểu đồ cho CustomModel tại: Comparative_Analysis/CustomModel_WUSTL_attack_comparison.png
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Đã lưu biểu đồ cho CustomModel2 tại: Comparative_Analysis/CustomModel2_WUSTL_attack_comparison.png
